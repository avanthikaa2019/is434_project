# %% [markdown]
# # SNSCRAPE

# %%
import snscrape.modules.twitter as sntwitter
import pandas as pd

# %% [markdown]
# ## NFT creator tweets

# %%
creators = ['gucci','adidas','adidasUS','burberry','LouisVuitton','balenciaga','dolcegabbana','RebeccaMinkoff',
            'KarlLagerfeld','bnv_me','nike','RTFKTstudios','Overpriced_NFT','auroboros_ltd','republiqec',
            'the_fab_ric_ant','SpaceRunnersNFT','MetaTriads','MAVIONworld','SohoKidsNFT','onclickcloset',
            'SCLadiesNFTs','mag_nezyum','web3fashion','DIGITALAX_','prada','balmain','ray_ban','superplastic',
           'givenchy','Bulgariofficial','MaisonValentino','fendi','jimmychoo','Guerlain','MetaBirkins','RalphLauren',
           'dressxcom','tribute_brand','dematerialised','XRCouture','carlingscom','McQueen','chanel','versace','michaelkors',
           'JPgaultier','lukso_io','jonathansimkhai','mmalhotraworld','pankajandnidhi','winkelstraatnl','chains_nft',
            'cryptojeweler','_Jacobandco','Rimowa','coach']

print("number of creators scraped:",len(creators))

print("query: NFT OR metaverse, english language, not retweet, from 1 Jan 2021 to 1 Mar 2022")

creator_tweets = []

# Using TwitterSearchScraper to scrape data and append tweets to list
for user in creators:
    for i,tweet in enumerate(sntwitter.TwitterSearchScraper('(NFT OR metaverse) from:'+ user + ' lang:en -is:retweet since:2021-01-01 until:2022-03-01').get_items()): 
        if i>10000: #number of tweets you want to scrape
            break

        #declare the attributes to be returned                                        
        creator_tweets.append([tweet.user.username, tweet.date, tweet.id, tweet.content, 
                             tweet.likeCount, tweet.retweetCount, tweet.replyCount, tweet.quoteCount, tweet.mentionedUsers]) 

    
creator_tweets_df = pd.DataFrame(creator_tweets, columns=['Username','Datetime', 'Tweet Id', 'Text', 'Likes', 
                                                 'Retweets', 'Replies',  'Quotes', 'Mentioned'])

print(creator_tweets_df.shape)
print(creator_tweets_df['Username'].value_counts())
# Out:
# number of creators scraped: 57
# query: NFT OR metaverse, english language, not retweet, from 1 Jan 2021 to 1 Mar 2022
# (3349, 9)
# cryptojeweler      969
# DIGITALAX_         934
# RTFKTstudios       301
# dematerialised     178
# SpaceRunnersNFT    142
# the_fab_ric_ant    125
# RepubliqeC         106
# bnv_me              97
# dolcegabbana        86
# dressxcom           63
# superplastic        56
# XRCouture           35
# AUROBOROS_LTD       32
# lukso_io            31
# Overpriced_NFT      31
# web3fashion         27
# givenchy            13
# onclickcloset       13
# SohoKidsNFT         11
# MetaTriads          11
# KarlLagerfeld       10
# MAVIONworld         10
# Coach                9
# gucci                8
# SCLadiesNFTs         7
# mag_nezyum           6
# RebeccaMinkoff       6
# _Jacobandco          6
# MaisonValentino      5
# Prada                4
# ray_ban              3
# Balmain              3
# Bulgariofficial      2
# Guerlain             2
# tribute_brand        2
# Burberry             2
# RIMOWA               2
# jimmychoo            1
# Name: Username, dtype: int64

# %% [markdown]
# ## media outlet tweets

# %%
media = ['glossyco','highsnobiety','voguemagazine','VogueFrance','BritishVogue','VogueRunway','VOGUEIndia','vogueaustralia',
         'VogueArabia','VogueLiving','voguebusiness','vogue_italia','VogueSpain','Vogue_Taiwan',
         'voguejp','VogueMexico','VogueKorea','VOGUERussia','VOGUE_Germany','NLVogue','voguescandi','vogueturkiye',
        'VogueThailand','HarpersBazaarSG','harpersbazaarus','BazaarArabia','harpersbazaarES','HarpersBazaarJP','ELLEfrance',
         'ELLEmagazine','ELLEUK','ELLEINDIA','elleindonesia','ElleCanada','ELLE_network','ELLESouthAfrica','ELLEaus',
         'Cosmopolitan','CosmopolitanUK','Cosmopolitan_IT','CosmopolitanSA','cosmo_ph','esquire','EsquireUK','EsquirePH',
         'esquiresg','EsquireME','esquireru','CosmopolitanNL','Cosmopolitan_es','Cosmopolitan_fr','Allure_magazine',
         'GQMagazine','BritishGQ','GQAustralia','gqindia','GQStyle','GQdotcoza','VanityFair','TheCut','Dazed','i_D','NylonMag',
         'TeenVogue','wwd','vmagazine','femalesingapore','nytimes','papermagazine','marieclaire','rollingstone','billboard',
         'time','Fashionista_com','VogueRunway','FashionWeek','BoF','InStyle','TimesFashion','NYTFashion','LondonFashionWk',
         'wmag','glamourmag','GraziaUK','Grazia','GraziaIndia','Grazia_me','graziatweets','BazaarUK','GlamourMagUK',
         'StylistMagazine','lofficielsg','voxdotcom','wired','wiredUK','NewYorker','RedMagDaily','marieclaireuk','BFC',
         'TatlerAsia','tatlersingapore','Prestige_SG','NYLONSG']

print("number of media scraped:",len(media))
print("query: NFT OR metaverse, english language, not retweet, from 1 Jan 2021 to 1 Mar 2022")

media_tweets = []

for user in media:
    for i,tweet in enumerate(sntwitter.TwitterSearchScraper('(NFT OR metaverse) from:'+ user + ' lang:en -is:retweet since:2021-01-01 until:2022-03-01').get_items()): 
        if i>10000: #number of tweets you want to scrape
            break

        #declare the attributes to be returned                                        
        media_tweets.append([tweet.user.username, tweet.date, tweet.id, tweet.content, 
                             tweet.likeCount, tweet.retweetCount, tweet.replyCount, tweet.quoteCount, tweet.mentionedUsers]) 

    
# Creating a dataframe from the tweets list above 
media_tweets_df = pd.DataFrame(media_tweets, columns=['Username','Datetime', 'Tweet Id', 'Text', 'Likes', 
                                                 'Retweets', 'Replies',  'Quotes', 'Mentioned'])

print(media_tweets_df.shape)
print(media_tweets_df['Username'].value_counts())
# Out:
# number of media scraped: 103
# query: NFT OR metaverse, english language, not retweet, from 1 Jan 2021 to 1 Mar 2022
# (1039, 9)
# voguebusiness      173
# WIRED               78
# Dazed               77
# billboard           75
# TIME                73
# RollingStone        67
# highsnobiety        55
# wwd                 52
# nytimes             51
# glossyco            41
# TatlerAsia          31
# BoF                 29
# WiredUK             20
# esquiresg           18
# TheCut              17
# VanityFair          17
# VogueRunway         12
# NewYorker           11
# papermagazine        9
# i_D                  9
# BFC                  9
# graziatweets         9
# GlamourMagUK         9
# GQMagazine           9
# voguemagazine        8
# BritishVogue         8
# BritishGQ            7
# NylonMag             7
# voxdotcom            6
# Fashionista_com      5
# VogueFrance          5
# VOGUEIndia           5
# esquire              5
# BazaarArabia         3
# EsquirePH            3
# Vogue_Taiwan         3
# LondonFashionWk      3
# Grazia_me            3
# ELLEmagazine         2
# NYTFashion           2
# wmag                 2
# ELLEUK               2
# ELLEfrance           1
# ELLEINDIA            1
# GraziaIndia          1
# EsquireME            1
# vmagazine            1
# GraziaUK             1
# esquireru            1
# VogueArabia          1
# harpersbazaarus      1
# Name: Username, dtype: int64

# %%
creator_tweets_df
# Out:
#      Username                  Datetime             Tweet Id  \
# 0       gucci 2022-02-18 15:55:55+00:00  1494702224538279947
# 1       gucci 2022-02-18 15:55:53+00:00  1494702219249307650
# 2       gucci 2022-01-21 18:22:22+00:00  1484592221823324162
# 3       gucci 2022-01-21 18:15:59+00:00  1484590616080224259
# 4       gucci 2022-01-20 14:41:49+00:00  1484174328287490057
# ...       ...                       ...                  ...
# 3344    Coach 2021-12-17 17:19:23+00:00  1471892793773760513
# 3345    Coach 2021-12-17 17:13:50+00:00  1471891398135881728
# 3346    Coach 2021-12-17 16:41:35+00:00  1471883284447739910
# 3347    Coach 2021-12-16 21:26:22+00:00  1471592564579000321
# 3348    Coach 2021-12-16 16:47:57+00:00  1471522497883480065
#
#                                                    Text  Likes  Retweets  \
# 0     Inspired by a profound desire to explore new p...     36         3
# 1     Vault aims to embrace Web3 by delving deep int...     43        10
# 2     For a preview of our roadmap: #SUPERGUCCI will...    672       112
# 3     gm, the House is delighted to announce its lau...   1207       328
# 4     @adidasoriginals Welcome Fren, 2022 is the yea...     70        24
# ...                                                 ...    ...       ...
# 3344  @AB_solo You can try again tomorrow… or the ne...      1         0
# 3345  @KaddouraHoussam The made-to-order Rogue bag i...      4         0
# 3346  @Thatjpeg_ Our first NFT will be available at ...     24         1
# 3347  @uuuulllii We’re offering a limited quantity o...     37         4
# 3348  ✨ Why we’re entering the NFT space: to mark th...    161        12
#
#       Replies  Quotes                              Mentioned
# 0           1       0                                   None
# 1           1       1                                   None
# 2          65      18     [https://twitter.com/superplastic]
# 3         187     140          [https://twitter.com/discord]
# 4           9       6  [https://twitter.com/adidasoriginals]
# ...       ...     ...                                    ...
# 3344        2       0          [https://twitter.com/AB_solo]
# 3345        1       0  [https://twitter.com/KaddouraHoussam]
# 3346       11       0        [https://twitter.com/Thatjpeg_]
# 3347        4       0        [https://twitter.com/uuuulllii]
# 3348       10       3                                   None
#
# [3349 rows x 9 columns]

# %% [markdown]
# ## to csv

# %%
media_tweets_df.to_csv('media_tweets-010121-010322.csv', index=False)
creator_tweets_df.to_csv('creator_tweets-010121-010322.csv', index=False)
print('done')
# Out:
# done

# %% [markdown]
# ## account info

# %%
account_info = []

for i in creators:
    userScraper = sntwitter.TwitterUserScraper(i)
    userdata = userScraper._get_entity()
    account_info.append([i,userdata.followersCount,userdata.statusesCount,userdata.verified])
    
for i in media:
    userScraper = sntwitter.TwitterUserScraper(i)
    userdata = userScraper._get_entity()
    account_info.append([i,userdata.followersCount,userdata.statusesCount,userdata.verified])

account_info_df = pd.DataFrame(account_info, columns=['Username','Followers', 'Tweets', 'Verified'])

# %%
account_info_df
# Out:
#             Username  Followers  Tweets  Verified
# 0              gucci    6719576   11491      True
# 1             adidas    4133161   14189      True
# 2           adidasUS     982921   47655      True
# 3           burberry    8201226   14208      True
# 4       LouisVuitton    9322808    7117      True
# ..               ...        ...     ...       ...
# 155              BFC     303566    6864      True
# 156       TatlerAsia      11107   18173      True
# 157  tatlersingapore       1834    2145     False
# 158      Prestige_SG        874    3517     False
# 159          NYLONSG      15002   14993     False
#
# [160 rows x 4 columns]

# %%
account_info_df.to_csv('account_info-010121-010322.csv', index=False)

# %% [markdown]
# ## from csv

# %%
media_tweets_csv = pd.read_csv('raw twitter data/media_tweets-010121-010322.csv')
creator_tweets_csv = pd.read_csv('raw twitter data/creator_tweets-010121-010322.csv')

media_tweets_csv
# Out:
#         Username                   Datetime             Tweet Id  \
# 0       glossyco  2022-02-26 21:00:05+00:00  1497677875876663310
# 1       glossyco  2022-02-23 16:01:20+00:00  1496515528546033666
# 2       glossyco  2022-02-19 20:00:24+00:00  1495126139764891652
# 3       glossyco  2022-02-19 15:00:42+00:00  1495050716553035776
# 4       glossyco  2022-02-15 16:00:00+00:00  1493616089842032650
# ...          ...                        ...                  ...
# 1034  TatlerAsia  2021-10-19 12:54:34+00:00  1450445267258548225
# 1035  TatlerAsia  2021-10-05 15:04:06+00:00  1445404437078544394
# 1036  TatlerAsia  2021-10-05 09:58:39+00:00  1445327567855235076
# 1037  TatlerAsia  2021-09-21 14:05:09+00:00  1440316171681632267
# 1038  TatlerAsia  2021-05-24 01:31:19+00:00  1396639918819102722
#
#                                                    Text  Likes  Retweets  \
# 0     Metaverse launches have been frequent in the l...      0         1
# 1     Metaverse launches have been frequent in the l...      0         0
# 2     Positioned as a physical metaverse influencer ...      0         0
# 3     Marketers discussed ways into the metaverse, a...      1         0
# 4     Positioned as a physical metaverse influencer ...      0         0
# ...                                                 ...    ...       ...
# 1034  Poly Auction Hong Kong is joining hands with d...      0         0
# 1035  The Hong Kong director celebrates the 30th ann...      1         1
# 1036  Poly Auction Hong Kong is joining hands with d...      2         0
# 1037  The Hong Kong director celebrates the 30th ann...      1         0
# 1038  Luxury luggage brand, Rimowa, on their first-e...      0         0
#
#       Replies  Quotes                                          Mentioned
# 0           0       0                                                NaN
# 1           0       1  [User(username='gucci', id=16913418, displayna...
# 2           0       0                                                NaN
# 3           0       0                                                NaN
# 4           0       1  [User(username='_Stylion_', id=398997784, disp...
# ...       ...     ...                                                ...
# 1034        0       0                                                NaN
# 1035        1       1                                                NaN
# 1036        0       1                                                NaN
# 1037        0       0                                                NaN
# 1038        0       0                                                NaN
#
# [1039 rows x 9 columns]

# %% [markdown]
# ## word clean up set up

# %%
import numpy as np
import re
from nltk.tokenize import sent_tokenize, word_tokenize, RegexpTokenizer
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
import matplotlib.pyplot as plt

stop_list = stopwords.words('english')
stop_list += ['would', 'said', 'say', 'year', 'day', 'also', 'first', 'last', 'one', 'two', 
              'told', 'three', 'since', 'nft', 'metaverse','amp','project','nfts']

def clean_tweet(tweet):
    if type(tweet) == np.float:
        return ""
    temp = tweet.lower()
    temp = re.sub("'", "", temp)
    temp = re.sub("@[A-Za-z0-9_]+","", temp)
    #temp = re.sub("#[A-Za-z0-9_]+","", temp) #keep hashtags?
    temp = re.sub(r'http\S+', '', temp)
    temp = re.sub('[()!?]', ' ', temp)
    temp = re.sub('\[.*?\]',' ', temp)
    temp = re.sub("[^a-z0-9]"," ", temp)
    temp = temp.split() 
    temp = [w for w in temp if not w in stop_list]
    temp = " ".join(word for word in temp)
    return temp

print("done")
# Out:
# done

# %% [markdown]
# ## tweet text processed

# %%
media_text_list = media_tweets_csv['Text'].tolist()
media_results = [clean_tweet(tw) for tw in media_text_list]
print('done')
# Out:
# done
# C:\Users\banna\AppData\Local\Temp/ipykernel_92256/767197126.py:13: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   if type(tweet) == np.float:

# %%
creator_text_list = creator_tweets_csv['Text'].tolist()
creator_results = [clean_tweet(tw) for tw in creator_text_list]
print('done')
# Out:
# done
# C:\Users\banna\AppData\Local\Temp/ipykernel_92256/767197126.py:13: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   if type(tweet) == np.float:

# %%
media_results
# Out:
# ['launches frequent brands including gucci adidas launching according new data retail consumers across uk us still unaware applications benefits',
#  'launches frequent brands like launching according new data consumers uk us still unaware applications benefits story',
#  'positioned physical influencer creator hub 1 2 million square foot emcee studio opening downtown l later part emcees expansion',
#  'marketers discussed ways among topics digiday medias cmo summit',
#  'positioned physical influencer creator hub 1 2 million square foot emcee studio opening downtown l later part emcees expansion story',
#  'latest hire styling track record daphne guinness story',
#  'delving skin market collection marries utility luxury design move suggests could become go path industry veterans story',
#  'january dtc underwear brand meundies posted twitter joined collection bored ape yacht club reaction company received less positive story',
#  'complete influencers product launches branded beauty event come story',
#  'register webinar january 26 1 p est discussion retailers consumers approaching 2022 sponsored',
#  'land virtual worlds like decentraland getting bought fashion brands rethinking approach setting shop story',
#  'recently collaborated collection featuring previously worked limited edition luxury fashion toys follow story balmainxbarbie',
#  'ces anticipated irl comeback muted pandemic driven cancellations beauty still present las vegas',
#  'join virtual event january 26 1 p est learn brands drive traffic conversation within virtual retail space sponsored',
#  'third month fashion series looking brands entered space matters bringing table',
#  'month streetwear brands battling biggest acquisitions fast fashion brands opening potential digital worlds',
#  'l al paris enters space support women worth philanthropy',
#  'glossy week review podcast discussed ralph lauren ambitions pete davidson partnership calvin klein chanel advent calendar controversy',
#  'british fashion awards new addition red carpet ar digital fashion digital accessory worn multiple celebrities designed institute digital fashion sold',
#  'partnering fashion retailer japanla city organizations like downtown santa monica inc across u flickpay app aiming bring digital collectible real world ar',
#  'art basel miami beach made pandemic comeback weekend beauty brands joined throngs well heeled collectors gallerists evangelists scenesters flocking event',
#  'second month fashion series looking brands entered space matters bringing table',
#  '3 fashion brands entered november',
#  'second month fashion series looking brands entered space matters bringing table',
#  'bring fashion media age',
#  'charlotte tilbury steps',
#  'launching wednesday original penguin fashion brand use tiktok content working directly tiktokers support talents',
#  'week glossy week review podcast discussed fashion responsibility environment nike entering american eagle acquiring another shipping logistics company',
#  'week review cop26 nike american eagle shipping acquisitions',
#  '5 brands launched september',
#  'new series glossy looking brands entered past month matters bringing table',
#  'aiming reset brand image dolce gabbana come collection step right direction',
#  'makes g different rest',
#  'brands dipped toe digital pond varying strategies eager take advantage boom drives collections sell minutes',
#  'fashion brands navigating next',
#  'second season fashion beauty event crypto fashion week secured major brand partners crypto fashion week held february 2021 multiple mainstream fashion beauty brands joined wave',
#  'following fashion brands independent beauty founders major beauty companies getting craze',
#  'craze includes major beauty brands',
#  'makes brand hit miss',
#  'dozen nail artists fashion beauty brands including multiple perfume companies launched non fungible tokens past months e l f cosmetics latest sell initial line june',
#  'market boomed six months moving world art fashion brands like gucci designers like jeff staple started selling virtual products',
#  'youre wearing balenciaga even',
#  'reactions bapes new include make stop',
#  'reactions bapes new include make stop',
#  'exactly case giant vs little guy fight ownership major ramifications industry',
#  'guccis plunge seems beckon come waters fine',
#  'philipp plein soon invade plein plaza 1 4 million plot decentraland',
#  'love hate space',
#  'hill mark zuckerberg wont stop running fact hill humanoid ceo might die',
#  'interview 2022 footwear vanguards series speak joey khamis putting innovative designs whole new',
#  'bots swatted initial drop gucci rearranging drop',
#  'hill mark zuckerberg wont stop running fact hill humanoid ceo might die',
#  'justin bieber purchased 1 3 million big deal',
#  'moon lamborghinis collection appropriately space themed',
#  'moon boot auction closed via worry yall cop pair boots matching sweater tomorrow 9 est 3 pm cet via highsnobiety shop',
#  'enter collaborative moon boot auction via',
#  'blockchain foundation mcqs creative community creation collection makes perfect sense',
#  'highsnobiety officially entered game reporting rise fashion space felt fitting made',
#  'highsnobiety officially entered game reporting rise fashion space felt fitting made',
#  'weve teamed moon boot create 3 unique available january 24 9 est 3 pm cet purchase youll cop pair matching moon boots highsnobiety alpaca sweater',
#  'pradas adidas second driven entirely community',
#  'howdy weve teamed moon boot take new frontiers via stay tuned latest',
#  'according walmarts recent trademark filings megastore going',
#  'edgar plans lil heroes top five hottest upcoming collections launch',
#  'edgar plans lil heroes top five hottest upcoming collections launch',
#  'paris hilton iann dior brought big guns headtripz collection',
#  'someone somewhere florida currently bidding melania trumps hat face',
#  'chains mere collectibles turning digital accessories irl ice',
#  'wont someone think poor bored ape collectors',
#  'analyze seismic impacts fashion industry loss virgil abloh industry shaking move',
#  'adidas originals bought bored ape yacht club dropping collection',
#  'adidas originals bought bored ape yacht club dropping collection',
#  'nike acquired rtfkt signaling desire get',
#  'taking wedding online',
#  'kanyes personal donda vests real yeezy grail scooped cool 75k christies auction came free',
#  'getting scented',
#  'jimmy wales talks wikipedias',
#  'rock full balenciaga fit inevitable',
#  'finally embrace parag agrawal',
#  'dont need iphone',
#  'givenchy hops bandwagon',
#  'jw anderson enters',
#  'finally organic approach releases',
#  'sorry still skeptical cryptopunks general',
#  'legendary japanese artist entered space huge way naturally read meta right',
#  'another another drop',
#  'new sneaker models made collaboration li ning show look soullands latest copenhagen outing something',
#  'luxury label launches',
#  'sportswear company wade arena',
#  'flume zawada dropped caught duo discuss change music industry',
#  'blueprints',
#  'hanks grammy nominated producer keyon christ earlier week hip hop got release',
#  'nasa joined tribe',
#  'ever watch',
#  'search popular marketplaces type keywords like andy warhol nba spiderman nike inevitably looking fakes',
#  'rtfkt studios continued dominate fashion space',
#  'mary j blige superbowl look available',
#  'happy report sex shenanigans returned sex city week episode like',
#  'company exactly',
#  'mark zuckerberg wants meta eventually seen company',
#  'online social networking site host runway show collina strada mowalola gypsy sport may 27',
#  'research shows women make 15 crypto users number new women oriented groups working make sure left market',
#  'well know kate moss duty new works yes kate moss selling moss reveals intimate slice life',
#  'research shows women make 15 crypto users number new women oriented groups working make sure left market',
#  'still obscure tech dream lets decipher future meta chic',
#  'still obscure tech dream lets decipher future meta chic',
#  'still obscure tech dream lets decipher future meta chic',
#  'still obscure tech dream lets decipher future meta chic',
#  'photographer jesse frohman launched website auction 100 pictures session photoshoot portion proceeds raised go jed foundation',
#  'lingerie styling inspiration read key takeaways show',
#  'harry styles got treatment',
#  'harry styles got treatment',
#  'harry styles got treatment',
#  'fashion focused platform xydrobe created hyper realistic digital copy viral harry styles cardigan jw anderson',
#  'piece digital wearable art collezione genesi unveiled alta moda show venice fetched huge sums auction',
#  'piece digital wearable art collezione genesi unveiled alta moda show venice fetched huge sums auction',
#  'piece digital wearable art collezione genesi unveiled alta moda show venice fetched huge sums auction',
#  'designed peter dundas mary j blige superbowl look available',
#  'stefan cooke shaking monopoly new collection sims',
#  'kind virtual fashion show imvu online social networking site united real world labels collina strada gypsy sport mowalola freak city bruce glen mum made mimi wade expert creators',
#  'imvu online social networking site host runway show featuring collina strada mowalola gypsy sport details including watch',
#  'want sleep kate moss new video works take viewers home bed exclusive story',
#  'women carving space market',
#  'photographer hugocomte expanding beyond image must fashion',
#  'peri new colour invented represent 2022 cautious optimism',
#  'fashion focused platform xydrobe created hyper realistic digital copy viral harrystyles cardigan jw anderson',
#  'digital outfits xr vogue explores possibilities fashion',
#  'french luxury maison celebrating 200 years founder creator book apple tv documentary video game 200 collaborations read know man behind brand louis200',
#  'collaboration entering space exclusive collection inspired venice',
#  'already vogue business member members automatically registered attend members receive emailed instructions event detailing join vogue business yahoo experience offer expires monday 28 february midnight et',
#  'vogue business yahoo experience take place 23 march time show virtual island host hour event experience open exclusively vogue business members',
#  'paris fashion week pushing ahead support web 3 0 next generation internet partnership french tech startup',
#  'fashion dives headfirst leave sustainability strategies',
#  'already vogue business member members automatically registered attend members receive emailed instructions event detailing join vogue business yahoo experience',
#  'vogue business yahoo experience take place 23 march time show virtual island host hour event experience open exclusively vogue business members',
#  'already vogue business member members automatically registered attend members receive emailed instructions event detailing join vogue business yahoo experience find',
#  'journey save 30 vogue business annual membership offer expires monday 28 february',
#  'fashion luxury brands including joined official lineup ever fashion week mvfw hosted',
#  'fashion dives headfirst leave sustainability strategies',
#  'chairman fran ois henri pinault says luxury group ready willing experiment announcing rebound growth leading digital innovators years underperformance',
#  'navigating new agencies talk watch speak biggest agencies new consultancies best practice ushering fashion luxury brands new era find',
#  'roksanda created fashion week fashions flirtation building momentum roksanda institute digital fashion created wearable london fashion week find',
#  'already member members automatically registered attend members receive emailed instructions event detailing join vogue business yahoo experience',
#  'journey vogue business partnership yahoo dept 23 march event open vogue business members sign today save 30 standard annual rate discount code save30',
#  'trademark intellectual property valuable physically virtually brands legal teams playing catch find',
#  'influenced new york fashion week virtual blended fashion shows new york fashion week designers added elements catwalk experience find',
#  'sign today using code save30 benefit coverage latest news tech innovations sustainability developments plus members get exclusive access tracker experience watchlist much',
#  'prada dress gamers riders republic sports world prada pushing via partnership french gaming company ubisoft popular outdoor winter sports game find',
#  'gucci plans virtual world gen z sandbox housed brand gucci vault concept launches vintage gucci emerging labels space host immersive experiences find',
#  'sign today using code save30 benefit coverage latest news tech innovations sustainability developments plus members get exclusive access tracker experience watchlist much',
#  'fashion exec guide outline explain key technologies projects influential fashion across digital clothing mixed reality gaming beyond find',
#  'influenced newyorkfashionweek virtual blended fashion shows new york fashion week designers added elements catwalk experience find',
#  '30 discount offer annual vogue business membership ending soon sign today using code save30 benefit biggest saving ever offered gain access brand new tracker',
#  'created fashion week fashions flirtation building momentum roksanda institute digital fashion created wearable find',
#  'prada dress gamers riders republic sports world prada pushing via partnership french gaming company ubisoft popular outdoor winter sports game find',
#  'housed brand gucci vault concept launches vintage gucci emerging labels space host immersive experiences find',
#  'brands create servers attract enthusiasts share projects existing fans either approach gains projects attention eager audience',
#  'brands need look like future crm full engaged emotional relationship audience avatar',
#  'co creation users community access co ownership make stand luxury industry',
#  'rebound us increased marketing budgets investments digital innovation including helped l al grow sales 16 per cent 32 28 billion 2021 find',
#  '30 discount offer annual vogue business membership ending monday sign today using code save30 benefit biggest saving ever offered gain access brand new tracker',
#  'brands need look like future crm full engaged emotional relationship audience avatar',
#  'co creation users community access co ownership make stand luxury industry',
#  '30 discount offer annual vogue business membership ending soon sign today using code save30 benefit biggest saving ever offered gain access brand new tracker',
#  'happens luxury brand many experimenting wants change eliminate put market',
#  'key feature blockchains cant changed replicated deleted allowing authenticity ownership scarcity happens luxury brand wants change eliminate put market',
#  'brands create servers attract enthusiasts share projects existing fans either approach gains projects attention eager audience',
#  'happens luxury brand many experimenting wants change eliminate put market',
#  'lawsuit filed thursday southern district court new york latest series intellectual property legal battles related',
#  'explosion interest raising sorts new legal issues week filed lawsuit streetwear resale marketplace digital renders sneaker giant footwear sold stockx customers',
#  'front rows parties tickets digital outfit matters seasons relevant welcome fashion week',
#  'third quarter revenue increased 27 per cent 1 8 billion beating analyst expectations investments roblox winter escape world lured new younger shoppers',
#  'meta shocked investors announcing ever fall users conceding rival taking users time tiktokers dominating front rows fashion week meta win fashion',
#  'happy welcome punk club future bright wagmi tweeted founder built marketplace luxury brands',
#  'growing number brands introduced wide variety projects including',
#  'bernard arnault son jumping cryptopunks new profile picture days billionaire chairman signalled wariness bubble effects',
#  'releasing partnership crowd sourced digital artwork beeple style collage luxury newest iteration',
#  'beauty brands wishing make mark need tailored marketing flexible expectations willing take grassroots approach',
#  'fashion leather goods division spiked despite ongoing pandemic disruptions ceo bernard arnault discussed opportunity acquisitions next',
#  'releasing partnership crowd sourced digital artwork beeple style collage luxury newest iteration',
#  'beauty brands wishing make mark need tailored marketing flexible expectations willing take grassroots approach',
#  'invite social media platform become way create hype find audiences projects latest gateway brands including adidas gucci enter',
#  'stakes entering high pressure',
#  'releasing partnership crowd sourced digital artwork beeple style collage luxury newest iteration',
#  'unpack top advice emerging agencies',
#  'digital creatives make new generation influencers brands ramp partnerships emphasise co creation digital designs influence physical goods',
#  'unpack top advice emerging agencies',
#  'influencer marketing looks like broad range fashion brands including prada puma yoox creating avatars stand alongside likes shudu lil miquela common goal purpose driven community led',
#  'sneakerheads long tech trendsetters social drops ar try latest land grab cultural cachet find',
#  'time hire chief officer brands entering virtual stores ar gaming digital fashion shows many relied external partnerships internal expert team might horizon',
#  'sportswear giant acquired old digital fashion startup undisclosed sum purchase nike betting least part future retail lies',
#  'sportswear giant acquired old digital fashion startup undisclosed sum purchase nike betting least part future retail lies',
#  'opening shoppable experience eight gender neutral winter sportswear looks inspired polo sports line 1990s archive part fashion holiday season pivot',
#  'launched third pair trainers accompanied vip experiences linked upcoming collaboration physical pair celebrity gym dogpound new york los angeles',
#  'opening shoppable experience eight gender neutral winter sportswear looks inspired polo sports line 1990s archive part fashion holiday season pivot',
#  'launched third pair trainers accompanied vip experiences linked upcoming collaboration physical pair celebrity gym dogpound new york los angeles',
#  'winter 2021 index partnership unpack takes innovate retain relevance new services business models upcoming index available advanced members',
#  'winter 2021 index partnership unpack takes innovate retain relevance new services business models upcoming index available advanced members',
#  'brand appears could help make successful splash risk alienating millions loyal users new need emerging someone oversee integrate projects',
#  '8 december brand launches third pair trainers accompanied vip experiences linked upcoming collaboration physical pair celebrity gym dogpound new york los angeles',
#  'become est e lauder brand offer bid drive loyalty add marketing weight top products sign purposeful brand uses non fungible tokens',
#  'beauty brands wishing make mark need tailored marketing flexible expectations willing take grassroots approach',
#  'beauty brands wishing make mark need tailored marketing flexible expectations willing take grassroots approach',
#  'brand appears could help make successful splash risk alienating millions loyal users new need emerging someone oversee integrate projects',
#  'become est e lauder brand offer bid drive loyalty add marketing weight top products sign purposeful brand uses non fungible tokens',
#  'beauty brands wishing make mark need tailored marketing flexible expectations willing take grassroots approach',
#  'brands think come shouldnt necessarily think way mobile strategy console games really strategy',
#  'considered successor social media era within newsletter explore explain key technologies projects influential fashion across digital clothing ar gaming etc sign',
#  'days easy money fashion brands still make splash world',
#  'days easy money fashion brands still make splash world',
#  'considered successor social media era within newsletter explore explain key technologies projects influential fashion across digital clothing ar gaming etc sign',
#  'days easy money fashion brands still make splash world',
#  'considered successor social media era within newsletter explore explain key technologies projects influential fashion across digital clothing ar gaming etc sign',
#  'fashion becomes increasingly entrenched core gen z customer base spends time playing socialising shopping understanding full potential crucial',
#  'important element thinking trademark use average consumer confused argue less sophisticated consumers purely age',
#  'became est e lauder brand offer bid drive loyalty add marketing weight top products sign purposeful brand uses non fungible tokens',
#  'many relied external partnerships internal expert team might horizon',
#  'became est e lauder brand offer bid drive loyalty add marketing weight top products sign purposeful brand uses non fungible tokens',
#  'many relied external partnerships internal expert team might horizon',
#  'world blockchain innovations come fast furious non fungible token new acronym blockchain fast forward dao',
#  'increasingly becoming fashion go playground people spend time virtual worlds',
#  'world blockchain innovations come fast furious non fungible token new acronym blockchain fast forward dao',
#  'increasingly becoming fashion go playground people spend time virtual worlds',
#  'fashion early adopter technologies include 3d design social media extended reality gaming virtual spaces non fungible tokens key projects',
#  'instead selling beauty brand giving shoppers signed rewards scheme chance receive free products 10 years along editions artwork',
#  'world blockchain innovations come fast furious non fungible token new acronym blockchain fast forward dao different',
#  'brand appears could help make successful splash risk alienating millions loyal users new need emerging someone oversee integrate projects',
#  'brand appears could help make successful splash risk alienating millions loyal users new need emerging someone oversee integrate projects',
#  'fashion entered introducing new possibilities tech tools ar try gaming avatars interact digital worlds session summit explore fashion needs know',
#  'fashion entered introducing new possibilities tech tools ar try gaming avatars interact digital worlds session summit explore fashion needs know',
#  'brand appears could help make successful splash risk alienating millions loyal users new need emerging someone oversee integrate projects',
#  'fashion care used brands hype brands develop strategy session answer questions swept across industry',
#  'fashion care used brands hype brands develop strategy session answer questions swept across industry',
#  'today becoming brand offer bid drive loyalty add marketing weight top products sign purposeful brand uses non fungible tokens',
#  'brand appears could help make successful splash risk alienating millions loyal users new need emerging someone oversee integrate projects',
#  'brand appears could help make successful splash risk alienating millions loyal users new need emerging someone oversee integrate projects',
#  'brand appears could help make successful splash risk alienating millions loyal users new need emerging someone oversee integrate projects',
#  'connecting dots digital scarcity non fungible tokens offer way create digital items retain value mimics physical luxury goods',
#  'brand appears could help make successful splash risk alienating millions loyal users new need emerging someone oversee integrate projects',
#  'connecting dots digital scarcity non fungible tokens offer way create digital items retain value mimics physical luxury goods',
#  'brands entering virtual stores ar gaming digital fashion shows many relied external partnerships internal expert team might horizon time hire chief officer',
#  'brand appears could help make successful splash risk alienating millions loyal users new need emerging someone oversee integrate projects',
#  'live blockchain solutions additionally empower customer us value empowerment linked full transparency traceability product provide digital twin certificate antonio carriero',
#  'brand might motivated want participate sales resales allow brand continue making money secondary sales future sales',
#  'brands entering virtual stores ar gaming digital fashion shows many relied external partnerships internal expert team might horizon time hire chief officer',
#  'brands entering virtual stores ar gaming digital fashion shows many relied external partnerships internal expert team might horizon time hire chief officer',
#  'initial hype wave crests brands exploring different options game proven successful among brands including',
#  'really strategy want people engage brand going benefit experience',
#  'fashion becomes increasingly entrenched core gen z customer base spends time playing socialising shopping understanding full potential crucial',
#  'fashion enthusiastic adoption digital avatars vr activations gaming partnerships offer fertile ground build relationships gen z raises new ethical challenges including gender race representation',
#  'really strategy want people engage brand going benefit experience',
#  'fashion becomes increasingly entrenched core gen z customer base spends time playing socialising shopping understanding full potential crucial',
#  'fashion enthusiastic adoption digital avatars vr activations gaming partnerships offer fertile ground build relationships gen z customers raises new ethical challenges gender race representation',
#  'fashion becomes increasingly entrenched core gen z customer base spends time playing socialising shopping understanding full potential crucial',
#  'brands queuing experiment virtual activations particularly fashion sphere ar try vr showrooms fashion games front mind fashion brands hoping catch new marketing wave',
#  'brands queuing experiment virtual activations particularly fashion sphere ar try vr showrooms fashion games front mind fashion brands hoping catch new marketing wave',
#  'inside roblox opportunity fashion new opportunity reach gen z christina wootton vp brand partnerships roblox explains brands make',
#  'fashion tech funding boom funded surge investment venture capitalists luxury brands includes virtual clienteling circular business models supply chains',
#  'inside roblox opportunity fashion new opportunity reach gen z christina wootton vp brand partnerships roblox explains brands make',
#  'games became luxury fashion ramp week louis vuitton burberry enter world non fungible tokens video games whose built consumer base eases transition toward digital items value',
#  'fashion exec guide outline explain key technologies projects influential fashion across digital clothing mixed reality gaming beyond',
#  'ray ban facebook pitch smart glasses amid boom facebook ray ban parent luxottica rolling 299 smart glasses allow people capture hands free images listen music make calls',
#  'inside roblox opportunity fashion new opportunity reach gen z christina wootton vp brand partnerships roblox explains brands make find',
#  'fashion becomes increasingly entrenched core gen z customer base spends time playing socialising shopping understanding full potential crucial',
#  'end web 2 0 connected people heading web 3 0 connects people places things extension comes next human creativity fashion industries change forever',
#  'fashion becomes increasingly entrenched core gen z customer base spends time playing socialising shopping understanding full potential crucial',
#  'considered next stage use technology successor internet age depending ask extend digital fashion social media augmented reality virtual stores video games',
#  'ar may means fashion prove valuable expected give renewed momentum view launch collezione genesi wearables expected include ar today',
#  'ar may means fashion prove valuable expected give renewed momentum view launch collezione genesi wearables expected include ar 28 august',
#  'connecting dots digital scarcity non fungible tokens offer way create digital items retain value mimics physical luxury goods',
#  'ar may means fashion prove valuable expected give renewed momentum view launch collezione genesi wearables expected include ar 28 august',
#  'connecting dots digital scarcity non fungible tokens offer way create digital items retain value mimics physical luxury goods',
#  'british jeweller royal warrant planning release sold digital physical pair meaning buyer acquires object digital representation object',
#  'british jeweller royal warrant planning release sold digital physical pair meaning buyer acquires object digital representation object',
#  'sales branded digital items legal brand nothing',
#  'people much interest people collecting things bragging rights imagine people collect image karllagerfeld eric pfrunder',
#  'smoke beginning clear initial hype cycle price tags level fashion brands harder time making big splash existing exchanges',
#  'nonprofit aurablockchainconsortium open luxury brand ability track trace product unique digital identity based brands collectively contributing blockchain governance strategy',
#  'people much interest people collecting things bragging rights imagine people collect image karllagerfeld eric pfrunder',
#  'smoke beginning clear initial hype cycle price tags level fashion brands harder time making big splash existing exchanges',
#  'nonprofit aurablockchainconsortium open luxury brand ability track trace product unique digital identity based brands collectively contributing blockchain governance strategy',
#  'people much interest people collecting things bragging rights imagine people collect image karllagerfeld eric pfrunder',
#  'luxury brands dominated conversation beauty brands seeing opportunity debuted series gets exclusive behind scenes look tapping hype',
#  'despite borrowing iconic birkin name style affiliation saw revenue sale',
#  'smoke beginning clear initial hype cycle price tags level fashion brands harder time making big splash existing exchanges',
#  'legal teams need educate potential issues might come people trying creative maybe someone wants use part gucci merge another brand brand hybrid',
#  'smoke beginning clear initial hype cycle price tags level fashion brands harder time making big splash existing exchanges',
#  'smoke beginning clear initial hype cycle price tags level fashion brands harder time making big splash existing exchanges',
#  'rules around creating physical counterfeits relatively clear rules still bit murky',
#  'work luxury jewellery debate running market diamonds luxury jewellery royal jeweller asprey plans issue others staying away',
#  'baby birkin legal scrutiny digital fashion digital fashion increases value relevance brands must consider show including much control want user generated content',
#  'despite borrowing iconic birkin name style herm affiliation saw revenue raises questions around ownership legality sales branded digital items legal brand nothing',
#  'want customers subject price volatility seeing marketplace today taking time explore jewellery related use cases create concrete benefits timothy iwata durie innovation director',
#  'sales branded digital items legal brand nothing',
#  'despite borrowing iconic birkin name style herm affiliation saw revenue sale',
#  'gucci expanding presence roblox gaming platform virtual week art installation vogue business exclusively reveal building brand awareness among young customers',
#  'gold rush already beginning days easy money fashion brands still make splash world',
#  'gucci expanding presence roblox gaming platform virtual week art installation vogue business exclusively reveal building brand awareness among young customers',
#  'smoke beginning clear initial hype cycle price tags level fashion brands harder time making big splash existing exchanges',
#  'smoke beginning clear initial hype cycle price tags level fashion brands harder time making big splash existing exchanges happens next',
#  'gucci recently confirmed matter time brand like release addition multiple industry sources number luxury fashion houses close releasing',
#  'new brings another breathless story new non fungible token record sale luxury fashion world remained relatively quiet change',
#  'thanks lot big supporting ever chinese magazine cover 30mins left end auction nftart nftartist',
#  'thanks adding bid 3 00 eth making history vogue taiwan',
#  'ever chinese magazine cover vogue taiwan july 2021 issue formosa love join bid time taiwan talented graphic designers acted creative director special edition vogue cover',
#  'kate moss ventures art market sharing intimate moments',
#  'middle eastern inspired carpet paintings digital designs embracing augmented reality jason seife using contemporary mediums bring traditional art form masses jasonseife art middleeasternart',
#  'refik anadol play perception suggests eerie possibility future non digital realities refikanadol art',
#  'october 7 contemporary milieu collectors artists musicians creators fashion designers architects chefs around world flock emirate abudhabi',
#  'important beeple',
#  'fashion latest destination',
#  'fashion latest destination',
#  'birkin everything need know handbag future',
#  'facebook name change social media company might called something else related',
#  'want marriage realestate bizarre',
#  'thursday recently freed westworld host announced company change name meta put extra focus virtual reality hellscape human beings doomed earth making memes',
#  'world art fewocious elite ascension auction house level required fight like hell get',
#  'world art fewocious elite ascension auction house level required fight like hell get',
#  'world art elite ascension auction house level required fight like hell get via',
#  'update beeples everydays sold 69m',
#  'features critically endangered animal',
#  'anything',
#  'mean human culture',
#  'join x discussing upcoming digital cover drop 12 months afterlife twitter spaces 31 january 11pm sgt 10am est',
#  'creative consultant round fashion maven mae tan marxmae wearing dmatxesquiresgxsats bell collectible sneaker streets get crypto',
#  'creative head sneakerhead wearing dmatxesquiresgxsats quarry collectible sneaker designed get crypto',
#  'update imperial phygital sold dmatxesquiresgxsats sneaker collection live click following links purchase bell collectible quarry collectible crypto',
#  'heres dmatxesquiresgxsats sneaker collection looks worn try imperial phygital bell collectible quarry collectible cryptocurrency crypto',
#  'dmatxesquiresgxsats sneaker collection quarry collectible purchase',
#  'dmatxesquiresgxsats sneaker collection imperial phygital purchase',
#  'dmatxesquiresgxsats sneaker collection bell collectible purchase',
#  'dmatxesquiresgxsats sneaker collection live click following links purchase bell collectible quarry collectible imperial phygital',
#  'try dmatxesquiresgxsats sneaker collection imperial phygital bell collectible quarry collectible',
#  'purchase esquire singapore 1 visit 2 enter shop discover click esquire x satoshi studio 3 click create profile 4 transact fiat cryptocurrency 5 look transaction confirmation profile page',
#  'heres sneak peek sneaker drip 1 lions prowl join us twitterspaces discussion artist tobyato fri 830pm sgt 730am est link crypto sneakers',
#  'join us twitterspaces discussion sneaker drip 1 lions prowl joined artist tobyato fri 830pm sgt 730am est twitter spaces link crypto',
#  'watch panel talk key players sneakers impact',
#  'heres purchase dmatxesquiresgxsats sneaker collection nftsneakers',
#  'vr already perfect match happens irl',
#  'fashions getting game weve round interesting luxury crypto creations',
#  'cause crypto billionaires 10 expensive sold far',
#  'headed next album going album nftcommunity nftartists nftdrop',
#  'prepared auction digital art dedicated 60th anniversary human spaceflight yuri gagarin part sale cover sent charity fund check',
#  'impact fashion may less new uniform schlubby tech bros like fantastical uniform new flush generation crypto investors',
#  'fashion obsessed',
#  'extremely rare wu tang album hands group',
#  'balenciaga joins fortnite',
#  'balenciaga joins fortnite',
#  'want people take art piece live real way never forget talent exodus',
#  'collectors see buying pair sneakers today equivalent copping pair air jordan 1s 1985',
#  'portfolio complete without shares pair rare air jordans',
#  'portfolio basketball highlights gamestonk complete without shares rare pair jordans',
#  '5 forgetful fintech bro back world hes neglected purchase new crease resistant pants choosing instead stick daggy old trackies clothes worth buying days form anyway',
#  'gq doctor horology resolves dilemmas perfect time make believe timepieces pros cons watch winders',
#  'fashions best foray yet',
#  'black badge edition even launched',
#  'quick selling new advent calendar releases latest fashion innovation',
#  'inside fashion industrys impending revolution',
#  'portfolio basketball highlights gamestonk complete without shares pair rare air jordans',
#  'snoop dogg consider greatest achievement entering sandbox performing dr dre super bowl name',
#  'tension born crypto believers tech journalists whose job includes reporting craze appear abating anytime soon',
#  'buzzfeed report identifying founders valuable collections drawn ire crypto community',
#  'melania trump auction hat watercolor digital artwork motion cryptocurrency sol',
#  'press release noted portion proceeds melania assist children aging foster care system big portion',
#  'melania vision priced around 150 pop watercolor former lady gaze includes audio recording voice',
#  'former lady offering eyes follow around mere 150',
#  'look ahead 2022 pace tech revolution getting faster darker ever read latest',
#  'interest extends beyond mark zuckerbergs latest rebrand better worse',
#  'emily ratajkowski created reclaim ownership instagram photo previously appropriated artist richard prince',
#  'emily ratajkowski created reclaim ownership instagram photo previously appropriated artist richard prince',
#  'news organizations jumping train',
#  'craze disrupting art world bitcoin billionaires gobble memeified art racist images feels like culture collapsing nothing makes sense may design',
#  'sophia robot already sensation working music career',
#  'ja rule sold original painting commissioned fyre offices plus digital ledger makes auction 122 000',
#  'ja rule sold original painting commissioned fyre offices plus digital ledger makes auction 122 000',
#  'craze disrupting art world bitcoin billionaires gobble memeified art racist images feels like culture collapsing nothing makes sense may design',
#  'girl four art basel parties determination find writes',
#  'girl four art basel parties determination find writes',
#  'girl four art basel parties determination find writes',
#  'girl four art basel parties determination find writes',
#  'sentence cheugy sold means absolutely nothing good get',
#  '23 old claims credit word selling cheugy',
#  'sentence cheugy sold means absolutely nothing good get',
#  'sentence cheugy sold means absolutely nothing good get',
#  '23 old claims credit word selling cheugy',
#  '23 old claims credit word selling cheugy',
#  'looking guide uses phantomthread analogies take seriously right place',
#  'looking guide uses phantomthread analogies take seriously right place',
#  'looking guide uses phantomthread analogies take seriously right place',
#  'looking guide uses phantomthread analogies take seriously right place',
#  'looking guide uses phantomthread analogies take seriously right place',
#  'looking guide uses phantomthread analogies take seriously right place',
#  'looking guide uses phantomthread analogies take seriously right place',
#  'cumming help new sex tech',
#  'mamoru hosoda engrossing new adventure belle see',
#  'cumming help new sex tech',
#  'mamoru hosoda engrossing new adventure belle see',
#  'announce maluma becomes face',
#  'announce maluma becomes face',
#  'group hit allegations racism past week spearheaded la artist ryder ripps',
#  'group hit allegations racism past week spearheaded la artist ryder ripps',
#  'model krystall schott face google image result face haunted 2016 nica belevan charlie curran accursed share seeks place power back hands',
#  'doubles palace smartens exclusive',
#  'iodf sending thierry mugler esque lukso blockchain',
#  'iodf sending thierry mugler esque lukso blockchain',
#  'doubles palace smartens exclusive',
#  'fashion focused site auctioning hyper realistic digital copy knitted look took 300 hours recreate',
#  'fashion focused site auctioning hyper realistic digital copy knitted look took 300 hours recreate',
#  'roblox host version irl ceremony presenting industry ever award design',
#  'cyber utopian fa ade crypto art spaces odds elitist underbelly go beneath decentralised veneer uncover mammoth effort make crypto world inclusive',
#  'cyber utopian fa ade crypto art spaces odds elitist underbelly go beneath decentralised veneer uncover mammoth effort make crypto world inclusive',
#  'cyber utopian fa ade crypto art spaces odds elitist underbelly go beneath decentralised veneer uncover mammoth effort make crypto world inclusive',
#  'track accompanies auction musician 2010 mixtape vicki leekx',
#  'track accompanies auction musician 2010 mixtape vicki leekx',
#  'track accompanies auction 2010 mixtape vicki leekx',
#  'work women artists makes 16 sales 21 months grimes crack top 10',
#  'work women artists makes 16 per cent sales 21 months crack top 10',
#  'rather smoking weed obsessed custom blunt look dazed cover shoot sign chance win dazed30 rihanna',
#  'work women artists makes 16 per cent sales 21 months crack top 10',
#  'mark zuckerberg living best life wear',
#  'rather smoking weed leaf fluttering windsmoking symbol obsessed custom blunt look dazed cover shoot sign chance win dazed30 rihanna',
#  'rather smoking weed leaf fluttering windsmoking symbol obsessed custom blunt look dazed cover shoot sign chance win dazed30 rihanna',
#  'rather smoking weed leaf fluttering windsmoking symbol obsessed custom blunt look dazed cover shoot sign chance win dazed30 rihanna',
#  'race',
#  'rather smoking weed leaf fluttering windsmoking symbol obsessed custom blunt look dazed cover shoot sign chance win dazed30 rihanna',
#  'rather smoking weed obsessed custom blunt look dazed cover shoot sign chance win dazed30 rihanna jawaraalleyne',
#  'bid build presence facebook looking hire 10 000 people european union next five years',
#  'race',
#  'tiktok dipping toe game debut collection featuring work everyone favourite internet troll',
#  'developed multi layered across physical space victoria albert museum',
#  'never seen footage sold along film memorabilia',
#  'model krystall schott face google image result face haunted 2016 nica belevan charlie curran accursed share seeks place power back hands',
#  'model krystall schott face google image result face haunted 2016 nica belevan charlie curran accursed share seeks place power back hands',
#  'sex workers sent panties space buy see',
#  'model krystall schott face google image result face haunted 2016 nica belevan charlie curran accursed share seeks place power back hands',
#  'model krystall schott face google image result face haunted 2016 nica belevan charlie curran accursed share seeks place power back hands',
#  'model krystall schott face google image result face haunted 2016 nica belevan charlie curran accursed share seeks place power back hands',
#  'balenciaga crashes marvel universe burberry steps',
#  'crashes marvel universe steps',
#  'future art looking boom done creators wild amounts money spent innovation take us next',
#  'join us today 6pm bst discuss five months boom afutureworld',
#  'future art looking boom done creators wild amounts money spent innovation take us next',
#  'join us thursday 6pm bst discuss five months boom afutureworld',
#  'cybr world magazine sold read excerpt digital pages',
#  'world magazine sold read excerpt digital pages',
#  'world magazine sold',
#  'model actress sex toy company co owner getting action 30 second long clip',
#  'new owners basquiat given option deconstructing physical artwork order ensure remaining form drawing',
#  'future world podcast series arts writer dean kissick founder marketplace zora dee goens go head head tokens everyone talking afutureworld',
#  'zo roth girl disaster girl meme made half million dollars selling original photo',
#  'university zo roth pictured smirking watched building burn child sold original photo',
#  'selling nonfungible token standing front artwork prince originally released 2014 part new portraits series',
#  'drawing late artist pulled auction allowed buyers destroy original artwork',
#  'new owners basquiat given option deconstructing physical artwork order ensure remaining form drawing',
#  'horrifying orwellian plot twist upcoming auction drawing jean michel basquiat allow winner destroy original artwork',
#  'new owners basquiat given option deconstructing physical artwork order ensure remaining form drawing',
#  'future world podcast series arts writer dean kissick founder marketplace zora dee goens go head head tokens everyone talking afutureworld',
#  'future world podcast series arts writer dean kissick founder marketplace zora dee goens go head head tokens everyone talking afutureworld',
#  'future world podcast series arts writer founder marketplace zora dee goens go head head tokens everyone talking hosted afutureworld',
#  'artworks capture intimate moments kate moss see',
#  'artworks capture intimate moments kate moss see',
#  'unnamed song selling',
#  'long x ae xii drops',
#  'aphex twin sold artwork 90 000 using portion proceeds going towards tree planting environmental projects',
#  'unnamed song selling',
#  'virtual artworks sold form proceeds going mf doom estate',
#  'digital editions iconic mask sold form proceeds going rapper estate',
#  'art warnymph collection vol 1 already brought 5 8 million',
#  'art warnymph collection vol 1 already brought 5 8 million',
#  'art warnymph collection vol 1 already brought 5 8 million',
#  'meanwhile jonathan anderson latest collection clapped back questioned role clothing digital world read',
#  'discord exposed undies heres paris fashion week mens recapped see',
#  'loewe aw22 menswear show clapback',
#  'loewe aw22 menswear show clapback',
#  'blockbuster collaborations rise unpack biggest industry',
#  'heres shaped fashion 2021 blockbuster collaborations rise unpack biggest industry read',
#  'everything need know night fashion awards tributes virgil abloh triumph went royal albert hall',
#  'andy warhol created 80s sold 3 38 million proving still ahead curve 1985 andy warhols artwork sold auction read',
#  'proving still ahead curve 1985 andy warhols artwork sold auction',
#  'listen closely hear entire groan',
#  'belle director tapped flower artist help design stunning gowns real life animes',
#  'know non fungible token peep coolest projects 2021',
#  'heres get piece biebs',
#  'ready',
#  'finally time learn',
#  'beeples art auction christies grimes 6 million worth digital art latest crypto craze taking creative scene',
#  'global beauty giant filed 17 trademark applications tied retail virtual perfume cosmetics',
#  'plein sport dropping 10 sneaker styles coming art counterpart',
#  'among brand plans experiences around argentinian roots twins physical items',
#  'company taking omnichannel approach linking experience physical purchases stores',
#  'glitterati technorati converged holograms projections themes strutted stuff week',
#  'included program retail pop partnership klarna vip dinner series performances artists weekend serve official countdown minkoff second collection drop march crypto fashion week',
#  'designer debuting collection comprising limited edition digital artworks moda platform',
#  'coach kate spade stuart weitzman continue find customers even',
#  'chief operating officer lisa bridgett ascends founder lucy yeomans shifts focus partnerships product',
# ...
#  'good world retailers must bake environmental social awareness strategies start argues doug stephens',
#  'blockbuster auctions grabbed many headlines technology new frontiers virtual worlds artificial intelligence data analytics apple privacy changes among bof top tech stories read',
#  'bofpodcast ceo c dric charbit discussed brand attention grabbing moments 2021 future',
#  'experimenting gaming virtual fashion brands unlock value streams engage young consumers find new routes creativity communities commerce',
#  'decentralisation key future nobody profit says martin raymond believe people profit moon think different',
#  'big tech giants signalled bold ambitions virtual world greatest concern operate closed society believe completely open place everyone go',
#  'next joe hage dial bofvoices explore whether open closed',
#  'sales dramatically spiked 2021 rising 10 7 billion q3 1 3 billion q2 according data gathered bof insights bofvoices',
#  'limitation style imagination alissa aulbekova co founder bofvoices',
#  'building bake security start like physical store advises gentry lane let security afterthought bofvoices',
#  'back afternoons session innovation speakers exploring new kinds technology mycelium mushrooms beyond bofvoices',
#  'level interactions brands consumers according ceo c dric charbit bofvoices',
#  'coming soon business unit director',
#  'virtual fashion blown brands dabbled gaming piled craze bubble next big thing',
#  'bofpodcast ledger chief experience officer ian rogers explains fashion tap gold rush featured fourth episode bof show streaming bloomberg quicktake',
#  'physical digital worlds merge luxury world dematerialise virtual space fast enough attract eager customers avatars',
#  'read latest bof insights report get bof perspective rise future digital assets plus playbook develop data driven strategy',
#  'announcing facebook rebrand meta mark zuckerberg offered vision dress',
#  'selling buying fashion brands dolce gabbana rebecca minkoff jump surging market',
#  'selling buying fashion brands dolce gabbana rebecca minkoff jump surging market',
#  'episode 5 transforming luxury bof new podcast presented bof spoke four global experts share insights impact future luxury goods host robin mellery pratt sponsored',
#  'fashion may preparing future retailers still need attend today business selling physical customers often physical stores',
#  'fashion may preparing future retailers still need attend today business selling physical customers often physical stores',
#  'week everyone talking earnings many fashion tech stars latest us inflation data things',
#  'dressing going enormously liberating potentially messy',
#  'couture simpsons balenciaga set style agenda 2021',
#  'limited edition bottle released blockbar 22 2 22 sold',
#  'going live 15 minutes watch presents jack irving bnv collection via lfw lfwclearpay',
#  'celebrate return london fashion week revealed latest cover magazine featuring bfcnewwave kai isaiah jamal soho house explore full lfw schedule via lfw lfwclearpay',
#  'thats hot gives explainer hottest crypto trend along look official',
#  'heres means everything know cryptos new art obsession',
#  'british stylist gemma sheppard become world stylist join',
#  'introduction blurs line physical virtual leading labels heading future new technicalfrontier',
#  'fashion real deal',
#  'upcoming collection plans rami kadi opens',
#  'came space race comes race',
#  'icymi karinnanobbs discusses based retail brands like gucci balenciaga made debuts',
#  'karinnanobbs discusses based retail brands like gucci balenciaga made debuts',
#  'parishilton polka dots always perfect combo favorite girl barbie vibe stylish trip nyc',
#  'vr set give wrinkles experts weigh explorations might affect faces irl offer simple solutions prevent sagging breakouts wrinkles',
#  'harrystyles cardigan dimensional digital replica developed team visual effects artists took 300 hours craft',
#  'demna gvasalia universe continues expand',
#  'demna gvasalia universe continues expand',
#  'isnt interesting sure',
#  'stay tuned much sells imagine huge',
#  'metaverses female users calling intimidation harassment rape threats done misogynys new home',
#  'putting stamp runway fashion week',
#  'like many areas finance women excluded movement heres get started',
#  'like many areas finance women excluded movement heres get started',
#  'destination',
#  'destination',
#  'welcome beauty new season surreal colour ethereal skin futuristic textures',
#  'welcome beauty new season surreal colour ethereal skin futuristic textures',
#  'welcome',
#  'facebook monopolize',
#  'becomes everything mark zuckerberg wants could shake world shifting existence rooted physical world digital presence increasingly supplements real',
#  'care facebook big push',
#  'facebook quietly buying',
#  'new interview mark zuckerberg explains effectively transition people seeing primarily social media company company',
#  'heck',
#  'quickly gig economy artists designers rushed service fast expanding space could forced adapt next big thing predict bubble burst',
#  'thirds freelancers fiverr servicing industry sustainable',
#  'youre probably going learn eventually might well',
#  'artists want experiment blockchain desire create environmental art seems conflict actual goal saving environment artist environmentalist',
#  'artists want experiment blockchain desire create environmental art seems conflict actual goal saving environment artist environmentalist',
#  '2022 art move beyond speculative frenzy early days everyday double digit growth via wiredworld2022',
#  'group supporting wikileaks founder julian assange raised 50 million ether cryptocurrency selling clock blockchain based activist collective set support legal bills via',
#  'opensea really foundation industry able support crazy growth via',
#  'going curated model cost opensea big slice crowd longs wild west ecosystem staying current light touch course bring endless string pr crises',
#  'group supporting wikileaks founder julian assange raised 50 million ether cryptocurrency selling clock blockchain based activist collective set support legal bills',
#  'zuckerberg narrative information technology culmination power reinforces grander myth progress myth stretches back 19th century shapes silicon valley self understanding',
#  'really wants work via',
#  'week gadget lab senior associate editor adrienne senior writer gilad edelman join podcast talk weird ins outs bringing family whether anyone actually want stay',
#  'mark zuckerberg dreams gamers extremely online people known years',
#  'week gadget lab senior associate editor adrienne senior writer gilad edelman join podcast talk weird ins outs bringing family whether anyone actually want stay',
#  'second life creator philip rosedale spoke wired avoid dystopian true value purely digital goods vr headsets suck',
#  'second life creator philip rosedale spoke wired avoid dystopian true value purely digital goods vr headsets suck',
#  'mentally replace phrase sentence cyberspace ninety percent time meaning wont substantially change',
#  'new plan lure social media users could legitimize could ruin',
#  'rage theres small problem major marketplaces art use energy scale small country 2021',
#  'confusion actually rights ownership entails already led high profile snafus',
#  'artists started using spatial virtual environments exhibition spaces company reacted fast virtual airbnb artists selling',
#  'facebooks hailed better form reality living version years taken video games coming world work',
#  'things make promise intriguing part already exist online games much remains promise unappealing impossible greedy',
#  'regulate join wiredhq conversation former congressman right ces2022 ces',
#  'future ces shows happen answers shares experience dont miss next wiredhq conversation starting 2 pm pt twitter ces2022',
#  'cars ces2022 join wiredhq conversation',
#  'describes next state internet consolidation marketing spin big tech increasing reach power big tech problem riddled bigger',
#  'might perfect time revisit podcast peter rubin wired contributor author book future presence facebook grand vision whether open platform agnostic version ever fully materialize',
#  'digital artist sold new dimensional video sculpture called human 29 million portrait human born even done rewired2021',
#  'digital artist sold new dimensional video sculpture called human 29 million portrait human born even done rewired2021',
#  'avedon built career wholly within confines internet long became silicon valley catchphrase du jour world took work meetings zoom',
#  'everyone talking theres spotlight vr scene new apps games new hardware even new use cases heres list favorite vr headsets',
#  'digital artist sold new dimensional video sculpture called human 29 million portrait human born even done rewired2021',
#  'mentally replace phrase sentence cyberspace ninety percent time meaning wont substantially change',
#  'seriously mean',
#  'mentally replace phrase sentence cyberspace ninety percent time meaning wont substantially change',
#  'rage theres small problem major marketplaces art use energy scale small country',
#  'facebooks hailed better form reality living version years taken video games coming world work via',
#  'digital artist sold new dimensional video sculpture called human 29 million portrait human born even done rewired2021',
#  'niantic ceo john hanke talks augmented reality destined suck',
#  'week gadgetlab hear acclaimed novelist neal stephenson climate change role fictional stories play shaping future',
#  'niantic ceo john hanke talks augmented reality destined suck',
#  'artists started using spatial virtual environments exhibition spaces company reacted fast virtual airbnb artists selling',
#  'artists started using spatial virtual environments exhibition spaces company reacted fast virtual airbnb artists selling',
#  'week gadget lab welcome wired editor large steven levy spoke hanke niantic countering facebooks vision',
#  'zuckerberg narrative information technology culmination power reinforces grander myth progress myth stretches back 19th century shapes silicon valley self understanding',
#  'digital artist sold new dimensional video sculpture called human 29 million portrait human born even done rewired2021',
#  'digital artist beeple talks human portrait human born piece sold night piece complete going continue changing updating piece rest life',
#  'niantic ceo john hanke talks augmented reality destined suck',
#  'niantic ceo john hanke talks augmented reality destined suck',
#  'open deserve happen mega corporations build trust enough allow deep interoperability',
#  'describes next state internet consolidation marketing spin big tech increasing reach power big tech problem riddled bigger',
#  'facebooks hailed better form reality living version years taken video games coming world work via',
#  'facebooks hailed better form reality living version years taken video games coming world work',
#  'week gadget lab wired senior writer arielle pardes joins us talk facebooks rebranding push challenges come shift',
#  'might perfect time revisit podcast peter rubin wired contributor author book future presence facebook grand vision whether open platform agnostic version ever fully materialize',
#  'today facebook attempted shift public attention towards future',
#  'everything marketplace right reeks 21st century tulip fever push aside zealous speculation something else going new funding model creative work yes even tweets',
#  'rage theres small problem major marketplaces art use energy scale small country',
#  'although anyone right click download artwork associated people like pablo rodriguez fraile buy tokens online auctions substantial cryptocurrency sums feel like real owners via',
#  'tim berners lee wrote source code world wide web early 1990s raised 5 4 million auctioning autographed copy non fungible token',
#  'week gadget lab talk peter rubin wired contributor author book future presence facebook grand vision whether open platform agnostic version ever fully materialize',
#  'want communicate real world brands place mass audiences true opportunity brand integration brand expansion brand expression',
#  'matters buzzword du jour facebook wants piece bad news zuckerberg ambitions sound boring hell',
#  'rage theres small problem major marketplaces art use energy scale small country',
#  'everything marketplace right reeks 21st century tulip fever push aside zealous speculation something else going new funding model creative work yes even tweets',
#  'fifth anniversary pok mon go craze marked launch celebration niantic ceo john hanke talks future gaming constructing calls real world',
#  'pandemic pushes us edge must choose path corporate control conflict abdicated responsibility true user sovereignty equal representation connected future benefits people via',
#  'tim berners lee wrote source code world wide web early 1990s raised 5 4 million auctioning autographed copy non fungible token',
#  'tim berners lee wrote source code world wide web early 1990s raised 5 4 million auctioning autographed copy non fungible token',
#  'rage theres small problem major marketplaces art use energy scale small country',
#  'want communicate real world brands place mass audiences true opportunity brand integration brand expansion brand expression',
#  'everything marketplace right reeks 21st century tulip fever push aside zealous speculation something else going new funding model creative work yes even tweets',
#  'major marketplaces art use energy scale small country',
#  'listen week gadget lab discuss nascent ecosystem like sell tweets',
#  'everything marketplace right reeks 21st century tulip fever push aside zealous speculation something else going new funding model creative work yes even tweets',
#  'major marketplaces art use energy scale small country',
#  'bubble taking gig economy',
#  'opensea marketplace cant win',
#  'assanges clock sale rides wave dao crowdfunding',
#  'big tech needs stop trying make happen',
#  'meta twitters landgrab could backfire',
#  'work look like 2022 hint',
#  'escapist fantasy games capitalism',
#  'companies already living zuckerberg',
#  'zany ascent art collectors',
#  'mark zuckerberg already sucks',
#  'need kick big tech',
#  'roblox wants build',
#  'scumbag steve nabbed 50 000 selling auction others disaster girl clarinet boy david dentist lining auctions next weeks',
#  'bad luck brian whose real name kyle craven finally saw fortunes change raked 35 000 worth crypto auction',
#  'zoe roth five years old dad snapped picture front burning building north carolina perfect meme material roth became known disaster girl 21 shes release image',
#  'arguably big shift online communication telephone internet 2021 going see rise',
#  'arguably big shift online communication telephone internet 2021 going see rise',
#  'arguably big shift online communication telephone internet 2021 going see rise',
#  'arguably big shift online communication telephone internet 2021 going see rise',
#  'arguably big shift online communication telephone internet 2021 going see rise',
#  'makers stuffed money writes every dimension way',
#  'makers stuffed money writes every dimension way',
#  'makers stuffed money writes every dimension way',
#  'makers stuffed money writes every dimension way',
#  'welcome facebook vast digital world go anywhere ads served anything generates ad revenue',
#  'welcome facebook vast digital world go anywhere ads served anything generates ad revenue',
#  'facebook called meta mark zuckerberg announced thursday time hope seen company yet kyle chayka wrote august portends digital life far clear mean',
#  'welcome facebook vast digital world go anywhere ads served anything generates ad revenue',
#  'welcome facebook vast digital world go anywhere ads served anything generates ad revenue',
#  'due recent ruling epic v apple apple longer fully control users pay things iphone apps mean anticipated era',
#  'earnings call week mark zuckerberg goal facebook help build exactly mean',
#  'wear dressing virtual world going enormously liberating potentially messy read via',
#  ...]

# %%
creator_results
# Out:
# ['inspired profound desire explore new playgrounds vault recently chose acquire parcels land sandbox voxel voxel bespoke world become eclectic space fostering boundary pushing creativity',
#  'vault aims embrace web3 delving deep creation nonfungible tokens lining shelves physical digital assets different eras ideas hybridize create perfect conditions spark new creativity future',
#  'preview roadmap supergucci vault part part drop beginning february 1st featuring 10 exclusive accompanied ceramic sculpture handmade italy co designed gucci guccivault',
#  'gm house delighted announce launch experimental space vault place foster open conversations community next join guccivault',
#  'welcome fren 2022 see guccivault',
#  'transcending confines time space ten supergucci created house represent visionary path experimentation discover drop alessandromichele guccivault',
#  'stepping new dimension guccivault supergucci launch synthetic celebrities enter space gucci past present future co exist discover drop',
#  'part special auction hosted gucci present unique artwork drawn gucciaria film co created alessandromichele proceeds going support covax',
#  'thebseries presents sharky b accessories collection styled tbmonogram exclusive burberry blanko vinyl toy available limited quantities collect game blankos block party today 11pm bst 3pm pst',
#  'thebseries gone fully digital created vinyl toy limited edition character sharky b accessories inspired tbmonogram game blankos block party available wednesday 11 august 11pm bst 3pm pst',
#  'new ultra feminine heroine projected hyper futuristic cyber world play realistic surrealistic inspirations dgfw22 women collection brings dolcegabbana aesthetic music',
#  'new ultra feminine heroine projected hyper futuristic cyber world play realistic surrealistic inspirations dgfw22 women collection brings dolcegabbana aesthetic music',
#  'new ultra feminine heroine projected hyper futuristic cyber world play realistic surrealistic inspirations dgfw22 women collection brings dolcegabbana aesthetic music',
#  'new ultra feminine heroine projected hyper futuristic cyber world play realistic surrealistic inspirations dgfw22 women collection brings dolcegabbana aesthetic music',
#  'new ultra feminine heroine projected hyper futuristic cyber world play realistic surrealistic inspirations dgfw22 women collection brings dolcegabbana aesthetic music',
#  'new ultra feminine heroine projected hyper futuristic cyber world play realistic surrealistic inspirations dgfw22 women collection brings dolcegabbana aesthetic music',
#  'new ultra feminine heroine projected hyper futuristic cyber world play realistic surrealistic inspirations dgfw22 women collection brings dolcegabbana aesthetic music',
#  'going live less 3 hours twitter space guests discuss highly anticipated dgfamily community launch today 6pm cet 12pm est',
#  'hosting twitter space partners guests discuss highly anticipated dgfamily community launch fri feb 25 6pm cet 12pm est',
#  'dolce gabbana highly anticipated dgfamily community launches soon digital physical experiential benefits take holders journey real life initial whitelist raffle link',
#  '10 latest details follow join discord visit discussing drop twitter space week special guests feb 25 6pm cet 12pm est',
#  '9 built leading layer 2 scaling solution dgfamily box minted eth layer 1 provenance integrated enable direct credit card payments via checkout solution',
#  '8 smoother experience boxes available via private mint whitelisted addresses selected via raffle awarded directly via join raffle sign via discourage bots hoarding requirements',
#  '4 black box bold mysterious holding grants access level dgfamily digital physical drops dolce gabbana apparel series digital events special bonuses along way including exclusive dolce gabbana swag set',
#  '2 drop follows dolce gabbana historic debut collezione genesi drop featured 9 kind personally designed domenico dolce stefano gabbana collectors included',
#  '1 dolce gabbana announce highly anticipated launch dgfamily community 3 distinct boxes digital physical experiential benefits take holders journey real life',
#  'historic collezione genesi debut september 2021 dolcegabbana continues transcend physical digital worlds launch exclusive dgfamily community collaboration discover dgnft',
#  'historic collezione genesi debut september 2021 dolcegabbana continues transcend physical digital worlds launch exclusive dgfamily community collaboration discover dgnft',
#  'historic collezione genesi debut september 2021 dolcegabbana continues transcend physical digital worlds launch exclusive dgfamily community collaboration discover',
#  '14 special thanks many partners made debut collection dolce gabbana successful especially whose tremendous support pos chain enabled fantastic user experience watch space',
#  '13 coming next dolce gabbana community exclusively partnership 4 exclusive levels including ultra exclusive gold level whose inaugural members winners collezione genesi auction coming soon',
#  '2 historic collection personally designed domenico dolce stefano gabbana exclusively remarkable level detail went every aspect 9 piece kind collection comes unrivaled digital physical experiential benefits',
#  '1 still amped week historic x dolce gabbana debut drop sold 1 885 719 eth making successful digital fashion drop ever theres much much come recap special collectors join dgfamily',
#  'dolce gabbana proud announce doge crown collezione genesi collection sold 423 5 eth 1 275 million total collection sold 1 885 719 eth 5 65 million historic much come',
#  'dolce gabbana proud congratulate winning lion crown historic collezione genesi collection sold 292 820 eth welcome family',
#  '3 doge crown inspired venice doge palace incredible piece took hundreds hours create hand features 7 blue sapphires 177 total carats 142 diamonds 6 28 total carats digital wearable physical crown 2 experiential access',
#  '2 lion crown inspired venetian coat arms incredible piece took hundreds hours create hand features 16 rubies 92 total carats 9 rose cut diamonds 1 5 total carats digital wearable physical crown 2 experiential access',
#  '1 7 auctions 2 go 1169 399 eth sales kinds history made dolce gabbanas debut collection 2 magical crowns remain lion crown doge crown whos got 20 hours left',
#  'dolce gabbana proud announce glass suit historic collezione genesi collection sold 351 384 eth 1 million truly historic reveal owner tomorrow 2 auctions go lfg',
#  'dolce gabbana proud congratulate third win historic collezione genesi collection dress dream gold sold 225 50 eth',
#  'unxd proud announce dress dream silver historic collezione genesi collection sold 188 10 eth',
#  'another look beautiful physical items associated todays dolce gabbana auctions pieces truly magical took thousands hours create auction closes 1 hour',
#  'next dolce gabbana want miss',
#  '404 415 eth across 4 debut dolce gabbana collection congratulations winners entire ecosystem made history everyone wins 5 auctions remain lfg',
#  'dolce gabbana congratulate winner golden impossible jacket historic collezione genesi collection sold 99 9 eth 286k welcome dgfamily',
#  'dolce gabbana proud announce mosaic impossible jacket second item collezione genesi collection sold 97 4359 eth 279k',
#  '1 bids dolce gabbana x collection crossed 707 eth 2 1m collection took insane 16 000 total hours create offer unrivaled digital physical experiential auctions close less 24 hours',
#  '10 join us twitter space tomorrow dolce gabbana enter final countdown collezione genesi auction miss',
#  '8 entire auction live bids live public already crossed 500 eth 1 5 million several days go auctions close less 2 days want miss',
#  '6 community dolce gabbana next roll dgfamily community 4 exclusive levels including ultra exclusive gold level whose inaugural members winners genesis auction similar approach digital physical experiential access',
#  '5 experience digital utility custom designed wearable physical utility corresponding physical asset 5 9 original signed sketch private atelier tour access dolce gabbana exclusive event alta moda couture unparalleled',
#  '2 provenance rarity entire collection personally designed domenico dolce stefano gabbana reference point ecosystem rare 9 iconic kind pieces made never made',
#  '1 bids dolce gabbana x collection already crossed 500 eth 1 5m collection took insane 16 000 hours total time create offer unrivaled digital physical experiential makes historic',
#  'bidding heats around dolce gabbana historic debut collection hosting special twitter space tomorrow together 24 hours auctions close want miss',
#  'bidding dolce gabbana x debut collection heating auctions live',
#  '4 primary currency auction eth new crypto ecosystem interested collection partnered order enable smooth easy onboarding experience',
#  '3 coming starting dolce gabbana dgfamily community exclusively partnership 4 exclusive levels including ultra exclusive gold level whose inaugural members winners genesis auction dropping oct 2021',
#  '1 bidding open dolce gabbana historic debut collection collezione genesi created exclusively partnership sure head create account place bids auctions close september 28 30th',
#  '16 built great platform incredible supporter creating collezione genesi auction take place eth minted layer 1 ethereum stay tuned week launch',
#  '15 collezione genesi auction dgfamily community form framework future reveal coming weeks want highlight genesis drop beginning start something truly special',
#  '14 coming next dolce gabbana community exclusively partnership 4 exclusive levels including ultra exclusive gold level whose inaugural members winners collezione genesi auction dropping october 2021',
#  '12 doge crown inspired venice doge palace incredible piece took hundreds hours create hand features 7 blue sapphires 177 total carats 142 diamonds 6 28 total carats digital wearable physical crown 2 experiential access',
#  '11 lion crown inspired venetian coat arms incredible piece took hundreds hours create hand features 16 rubies 92 total carats 9 rose cut diamonds 1 5 total carats digital wearable physical crown 2 experiential access',
#  '10 impossible tiara digital piece features spectacular gems quite found earth 63 striking red emeralds 713 turquoise blue paraiba tourmalines 50 extraterrestrial diamonds digital wearable hand sketch 1 experiential access',
#  '9 golden impossible jacket digital piece inspired st marks basilica golden mosaics entirely embroidered sequins 24 karat gold plated crocodile collar cuffs hem digital wearable hand sketch 1 experiential access',
#  '8 mosaic impossible jacket digital piece inspired mosaic floor st marks basilica entirely embroidered sequins deep green crocodile collar cuffs hem digital wearable hand sketch 1 experiential access',
#  '7 velvet impossible jacket digital piece inspired typical venetian brocade fabrics 24 karat gold thread gold crocodile inserts digital wearable hand sketch 1 experiential access',
#  '5 dress dream gold spectacular piece took thousands hours create hand features embroidery made swarovski crystal murano glass surface reflections incredible digital wearable physical dress 2 experiential access',
#  '4 glass suit incredible digital real world flex piece took thousands hours create hand features embroidery made swarovski crystal murano glass digital wearable physical suit 2 experiential access',
#  '3 dress dream silver spectacular piece took thousands hours create hand features embroidery made swarovski crystal murano glass surface reflections incredible digital wearable physical dress 2 experiential access',
#  '2 historic collection personally designed domenico dolce stefano gabbana exclusively remarkable level detail gone every aspect collection corresponding ecosystem transcends physical metaphysical world',
#  '1 today giving closer look debut dolce gabbana collection collezione genesi exclusively partnership 9 piece kind genesis collection comes unrivaled digital physical experiential benefits read',
#  '4 reveal dgfamily community future drops coming weeks believe important showcase genesis drop beginning start something truly special',
#  '3 dgfamily already sits heart everything clients family believe deep sense community reflects underlying ethos spirit crypto ecosystem makes special believe meaningfully contribute',
#  '1 announcing dolce gabbana community exclusively partnership 4 exclusive levels including ultra exclusive gold level whose inaugural members winners collezione genesi auction join dgfamily dropping october 2021',
#  'revealing collezione genesi bespoke collection dolce gabbana exclusively curated marketplace digital luxury culture 9 kind items digital physical experiential benefits auction starts sep 20th',
#  'revealing collezione genesi bespoke collection dolce gabbana exclusively curated marketplace digital luxury culture 9 kind items digital physical experiential benefits auction starts sep 20th',
#  'revealing collezione genesi bespoke collection dolce gabbana exclusively curated marketplace digital luxury culture 9 kind items digital physical experiential benefits auction starts sep 20th',
#  '5 successful projects debut collection story ends truly begins winning collectors hodlers assured exclusive surprises future',
#  '4 unxd deeply committed future ecosystem museum grade works genesis pieces form foundation everything else brand space partnership unxd',
#  '2 believe collection represents future way universe coexist integrated additive spent great deal time thinking create amazing experience collectors community',
#  '1 today big proudly reveal collezione genesi debut collection kind 9 piece collection personally designed domenico dolce stefano gabbana exclusively unxd',
#  'mon sep 6th well unveiling collezione genesi highly anticipated debut collection followed twitter space 6pm cet 12pm et discuss inspiration historic collection w guests',
#  'fashion history making dolce gabbana',
#  'exclusive feature dolce gabbana highly anticipated historic debut drop register',
#  'insightful session today bridging physical metaphysical thanks participants listeners stay tuned dolce gabbanas historic debut collection soon exclusively',
#  'honor domenico dolces birthday today reveal debut drop collezione genesi exclusively powered sure reserve place special limited edition',
#  'going live 2 hours 9am edt 3pm cet talking special guests dolce gabbanas debut drop go live exclusively dont miss',
#  'dropping news later week debut drop collezione genesi exclusively sure reserve place',
#  'popular demand hosting another spaces event special guest sign friday august 13 9am edt 3pm cet 6 30pm ist',
#  'less 1 month debut drop collezione genesi exclusively sure reserve place',
#  'register debut drop collezione genesi exclusively sure reserve place',
#  'icymi listen recording weeks special twitter spaces digital culture dggenesi',
#  'following weeks announcement debut drop exclusively well hosting special twitter spaces event digital culture thursday 3pm cet 6 30pm ist open dggenesi',
#  'dolce gabbana partners luxury marketplace present collezione genesi ever exclusive alta moda collection reserve spot',
#  'dolce gabbana proudly reveals dggenesi ever alta moda exclusive collection partnership luxury marketplace reserve spot link',
#  'best weekend aspen celebrating countdown upcoming drip grateful many able join us fun exciting things come rm stay tuned',
#  'second drip coming march countdown begins stay tuned dmatxrm',
#  'stay tuned drip coming soon',
#  'excited announce second collection drip launching crypto fashion week march check article info join us aspen weekend celebrate',
#  'guys opportunity shop digital merchandise collection featuring 4 full looks thanks destination digital fashion',
#  'partnered kind live immersive experience auction see link bio',
#  'show us youre taking new klxendless upload ar photos posewithkarl karlnftcollection',
#  'latest karlnftcollection meet karl x exclusive new addition family',
#  'account ready welcome karl x dropping 1 hour get ready karlnftcollection staytuned',
#  'exclusive exclusive collaboration exclusive surprise check read exclusive access youll receive karlnftcollection',
#  'available editions latest offer exclusive invitation vip event taking place paris 2022 karlnftcollection',
#  'new karlnftcollection drop happening tomorrow 4pm cet stay tuned karlnftcollection 24hourstogo',
#  'latest selection designed collaboration london based street artist karlnftcollection',
#  'imminent arrival prepared creating account get latest collectible created karlnftcollection via',
#  'latest karlnftcollection meet karl karl new features exclusive digitally rendered pieces actual karl karl capsule collection powered',
#  'welcome future meet ikonik karl karllagerfeld collection available read karlnftcollection',
#  'highlight quixotic collection presented built visit plot 60 22 close personal beautiful feather duster spiral dress visor outfit deep drop',
#  'really starting fill iconic fashion wearables incredible show',
#  'gm ozzy clone collection open minting registered whitelist starting 11am utc come serve youll need quick mint',
#  'launch second continue collaboration designer featuring piece extension highlighted show partnering',
#  'open 24 hour sale starting 9am utc lucky 15 head x page mint ozzy clone 15 lucky draw winners 24 hours mint ozzy clone collection',
#  'tech team clocked less 1 minute prismatic dress sold incredible congratulations team looking forward next phase coming days stay tuned',
#  'absolutely incredible breakthrough fashion design evolve',
#  'excited announce weve raised us 4m series funding round led supported number influential funds individuals enable bnv expand experiences initiatives across fashion gaming crypto',
#  'gm exciting news universe far far away fashion multiverse continues expand 5 airdrop winners ozzy clone phoned home congrats copenhagen fashion weeks attendee winners ozzy immutably',
#  'ready outfit ozzy clone collection brought di vision association landing',
#  'association di vision launches ready outfit ozzy clone collection bnv headlining',
#  'powered part collaboration di vision ozzy landing feb 3 earth near see futureoffashion brandnewvision metaversionfashion',
#  'doubled number brands digitalfashion platform gm fellow pioneers di vision join party discord',
#  'gm round 1 mint live bnv everyone else check image see chosen whitelist draw round 02 redraw starts january 18 uncollected discord sweetest updates digitalfashion bnvdrop',
#  'know designers making boodies even luxuriously haunted couture gg',
#  'fashion emerging deep starting decidedly human form factor friendly prismatic dress gm sneak peeks us whitelist draw sales start next week',
#  'happy new 2022 team bnv bnv digitalfashion nftdrop newyearpost',
#  'unlearn language imagine communication alphabet merely symbols signs assign meaning meaning nothing create something get brand 3d video',
#  'merry christmas bnv team may season full light laughter family real world bnv digitalfashion nftdrop christmas2021 nftcommunity nftcollector',
#  'hundred trillion dollars seems like lot except isnt balancing rocks modernism clash battle cash get brand 3d video bnv phoenixrising boodienftdrop nftdrop',
#  'eye sees melting away imagination see see eye represents new sight unseen origin 01 get designed phoenix rising 3d video bnv phoenixrising boodienftdrop',
#  'free alert simply retweet live twitter space talk post join 16th dec see thats cant simple click view event post bnv digitalfashion nftcollector freenft',
#  'join free fashion live ama talk 16th dec award winning designer hosted announce ar filter comp winners give away free join bnv digitalfashion',
#  'live prismatic dress iridescent mirrored dress designer ft virtual artist maie click whitelisted drop bnv digitalfashion nftdrop nftcollectors',
#  'absolutely welcome join competition dec 16th ama jawara alleyne holders get special shoutout',
#  '7 special thanks partner helped us make ar filter bullish fashion rewarding experience provide anyone started build lets go click',
#  '6 join live twitter ama dec 16 hold twitter spaces ama hosted amazing get know designer learn fashion get chance part something special working dropping soon',
#  '4 early member fashionmetaverse projects rewarding early select entrants show ama special priority something working coming near future',
#  '3 fashion community growing everyone gets whos real world counterpart worn get ready exciting upcoming drops designers like creator blunt dress',
#  '2 path build giving free ethereum convert cash currency like sand used wild high buy upcoming high profile fashion',
#  '1 call high end entries using ar filter originai dress worn made coveted fashion platform enter conversation bold entry creativity editing skills fashion sense',
#  'brand new vision giving away hundreds cash 3 people style best blunt dress ar using ar heres need know snap tweet',
#  'launching fashion experience giving away free eth learn bnv freeeth digitalfashion fashionmetaverse freenfts nftairdrop',
#  'winners announced congratulations winners recent drop blunt dress worn rihanna win go discord find designed 3d design video',
#  'separated gaming collectibles film see monsters bash collectibles zombies make creepily exciting list learn bnv meta halloween nftdrop sandbox',
#  'facebook along name change definitely bringing innovation adoption vision investments space truly good people read full article bnv digitalfashion',
#  'tdfg scholarship digital equity program partnering bnv offer another place next cohort digital fashion 101 apply learn tdfg digitalequity digitalfashion 3ddesign lifelonglearning',
#  'collaboration fashion designer independent fashion culture publishing powerhouse bnv led birth icon among fashion blunt dress read full article bnv nftcollector',
#  'shows dj music tech fashion collaboration makes performance come life metaversefestival follow',
#  'win blunt dress worn easy 10 exclusive available dont wanna miss free sign featured bnv digitalfashion freeairdrop',
#  'virtual world festival chock full music set launch oct 21 24 help admire paris hilton dress represents read full article bnv digitalfashion',
#  'next pleased announce iconic blunt dress worn rihanna digitals 30th anniversary issue win free sign bnv rihanna nftcommunity',
#  'super excited partner release blunt dress designed worn updates coming soon nftdrop rihanna nftdrops nftcommunity nftcollector',
#  'drop details bnv drop 1 quantity 101 featured attributes collection keep watch collab bnv x mishka brand bonus discount code type cap fitted style spiked color black material studded leather freenfts nftdrops nftcollectors',
#  'recent airdrop resounding success least wait see planned next stay tuned phase2 read full piece bnv freeairdrop nftdrop freenfts nftcollector',
#  'ceo richard hobbs reblikas mao lin liao recently discussed advantages purely digital fashion compared real world 3d tech festival 2021 click listen bnv digitalfashion',
#  'gift fashion web3 team creating brand experiences fitted gold 1 11 dm us address us drop',
#  'top 5 inviters excluding admin members get dropped pleasure pain spiked keep watch enjoy owner perks duration oct 4 2021 midnight utc 4 bnv bnvairdrops digitalfashion freeairdrop nftdrop nftcommunity',
#  'simply generate invite link discord server drop menu top left get friends anyone join track invites bnv bnvairdrops digitalfashion freeairdrop nftdrop nftcommunity nftcollector',
#  'entered ar filter competition yet simply make creative video filter tag bnv mishka win 1 11 ultra rare gold join discord bnv bnvairdrops airdrops',
#  'right sir',
#  'time learn win 1 2 exclusive bnv bnvairdrops nftdrop nftgiveaway nftcollector nftcollector digitalmarketing cryptoworld freenfts digitalfashion',
#  '101 free mishka rare legacy fams',
#  'official register win free rare legacy make sure like comment share post learn discord bnv bnvairdrops nftdrop nftgiveaway nftcollector nftcollector',
#  'fam ultra rare free mishka',
#  'ultra rare free mishka',
#  'ultra rare free mishka',
#  'right sir ultra rare free mishka',
#  'ultra rare free mishka',
#  '101 ever find discord bnv bnvairdrops digitalfashion nftdrop freenfts nftdrops nftgiveaways nftcollectors',
#  'free airdrops head discord bnv bnvairdrops digitalfashion nftdrop freenfts freenftshoutouts',
#  'check latest digital fashion drop page',
#  'list staff favorite massively multiplayer online games look 2021 read bnv digitalfashion nftdrop nftgaming gamers gamingcommunity',
#  'brand new visions founder richard hobbs shares brand story vision blockchain enabled fashion platform aims fashion goes digital click link bio read story bnv digitalfashion',
#  'wait video ads shirt bring another level interest engagement brand partners sponsors think creative possibilities drop us line bnv digitalfashion brandpromotions nftdrops',
#  'never sold digital clothing latest brands adapt digital world korean 3d avatar platform read bnv digitalfashion nftcollector nftdrop',
#  'communities among interesting ways dive world visa showed big companies investing communities blockchain looks like read bnv digitalfashion',
#  'digitalax global designer network partner 5 fashion week slew workshops auctions campaigns click read bnv digitalfashion nftcommunity',
#  'officially partners bring expertise digital fashion education bnvs fashion hub read full article bnv digitalfashion brandpartnerships motif nftdrops nftgiveaway',
#  'yip weve featured latest piece immaterial gains boom comes fashion click read bnv digitalfashion thefinancialtimes fashion branding entrepreneurs',
#  'partner strengthening mission take digital fashion exciting realms education click read full article bnv digitalfashion partnerships',
#  'major fashion brands transitioning cryptocurrency transactions burberry givenchy dolce gabbana dabbling learn bnv digitalfashion nftcommunity',
#  'adding content layers virtual fashion piece bnvs talented using bnv digitalfashion futurefashion unrealengine',
#  'fashion magazine vogue officially stepping world releasing series named mystery boxes learn bnv digitalfashion vogue',
#  'havent heard going digital coming soon read bnv digitalfashion nftcommunity',
#  'browzwear bnvs earliest engagements continues expand vision read bnv digitalfashion nftcommunity',
#  'relative novelty raised host legal issues many yet resolved click read bnv digitalfashion nftcommunity',
#  'bnv official partners bring expertise digital fashion education bnvs fashion hub read full article bnv digitalfashion brandpartnerships',
#  'father son virtual fashion artistic composition storytelling bnv digitalfashion digitaldesign',
#  'hiroto kai started design japanese inspired garments able make 15 000 20 000 weeks click read bnv digitalfashion nftcommunity',
#  'megan thee stallion team create kind virtual reality theatrical experience 2022 click read bnv digitalfashion nftcommunity megantheestallion',
#  'official campaign build digital storefront creates access brands hit huge milestone click read full article bnv digitalfashion',
#  'probably leading commentator imho things related commonly referred street fashion richard hobb ceo read bnv digitalfashion fashionnft bobbyhundreds fashiontwt',
#  'major fashion players finally joining game written click read full depth piece bnv digitalfashion',
#  'wow featured tech disruptor fashion industry read full article bnv digitalfashion',
#  'live entered visit revamped website learn new improved digital fashion movement bnv digitalfashion',
#  'game comingsoon bnv digitalfashion',
#  'loading comingsoon bnv digitalfashion',
#  'get coffee quick break read interview founder nftcollectibles fashion digitalart',
#  'lees 48 hours able win jackets add virtual wardrobe future proofed nftcollector fashion digitalart nftartists',
#  'clock ticking chance auction nftcollectors nftcollectibles digitalart digitalfashion',
#  'auction started iced piece 10 available already move go get bids nftcommunity nftcollectibles blockchain digitalart digitalfashion',
#  'original',
#  'curated fashion marketplace',
#  'live playing curated fashion focused platform nftcollector digitalart digitalfashion ethereum',
#  'fashion heading nftfashion ethereum',
#  'release include piece follow sign details nftcollector nftfashion cryptoart',
#  'thats working sb wont new',
#  'available game clone wallet directly linked via sb clone new lol thatd mess new native add clones',
#  'good',
#  'scouting great creators getting role rtfkt team weve always done thats started ecosystems building empower creators build together step step cant wait see youll invent',
#  'get gonna team building us',
#  'yeah careful scammers mint quest',
#  'killed',
#  'revolution amazing take toll mental health important matter rtfkt us stay zen take care creativity join movement',
#  'mnlth rtfkt powered r x dynamic artefact reveal technology',
#  'wait tell bit mlnth check pod step time build',
#  'loot pods work standalone btw even dont space pod use solo room connect space pod',
#  'building pod pod',
#  'casually building foundation together',
#  'introducing podx pods extension system loot pod airdrop initiated giving scale marble canvas loot designs cant wait see fill',
#  'pretty dope shouldnt able put 2 clones 1 display spot per cc',
#  'clones know clone dont bodies yet theyll need wearables take care lower part preparing 3d files step ecosystem preparing wearable pipeline drops clones',
#  'pods space pods done little step personal relatable space apartments next integrated 3d files display pods start something much bigger arent ones building',
#  'thing starts make sense',
#  'yes usuable anyone',
#  'space pods galleries made clone owners usable anyone total 20 000 space pods created space pod start home info use space pod',
#  'yes 1 spacepod per clone vial',
#  'yes share link people visit',
#  'gonna display pod',
#  'really pfp giving shot',
#  'dope',
#  'yes get airdrop clone wallet though use however want',
#  'road map 2022 clones incredible utilities deliver early next 3d files create content use video calls customization clone fashion items forging events rtfkt utilities',
#  'space pod airdrop item roadmap airdropped end month clones space pod 1 clone 1 space pod clones airdropped space pods unrevealed vials pay gas fee claim space pod',
#  'pre reveal clone x sneaky info dna aliens alien roughly 0 13 total clone supply aliens standing members ancient extinct highly advanced empire 15 alien murakami drip traits',
#  'pre reveal clone x sneaky info dna angel angels roughly 8 5 total clone supply born light guides featuringdivine angel type 15 angels murakami drip traits',
#  'gm soon well chillin space pods room display collection airdrop clones happening end dec many utilities upgrades weve prepared clone army',
#  'reminder ultra careful dms discord never dm block dms common servers discord settings usefull everyone space avoid scams many people getting stolen buying fake everyday',
#  'get image 3d utilities added clone x personalization site live q1 2022',
#  'clones forbes evolution brand rtfkt clonex drops today',
#  'remember lot selected presale free 1 0 1 eth creator collections lots people got us',
#  'final clone x giveaway celebrate clonex drop giving away x5 clone x enter 1 rt tweet 2 follow 3 tag frens x5 winners randomly selected 30th nov',
#  'yes dont buy used already vials burnt reveal bridge site',
#  'reminder avoid scams try buy mintdisc secondary probably used redeem already try buy presale access either risky cant wait public sale get dna vial collection',
#  'clone x pre sale live rtfkt qualified mintdisc owners follow instructions mint mint vial 48hrs mint issues discord presalehelp channel help',
#  'clones allowing presale access presale starts today super careful dyor',
#  'blockchain sophisticated even use redemption checker website might chance used minting remove bids existing qualify presale might end nothing',
#  'please aware presale live 12pm pt today careful buying offering buy something market somebody could mint sell afterwards dont recommend buy presale period cant guarantee mint',
#  'read previous tweets rtfkt owners specific collections needing mintdisc token presale',
#  'previous rtfkt owners items collections needing airdrop presale',
#  'rtfkt collections items needing mintdisc airdrop collections dont need disc presale items detected automatically site mint',
#  'reminder erc1155 shared ownership cant scan true owner presale site chain verification redemption whole airdrop process allow stay alert dont buy fake collections',
#  '100000th time whitelist way get presale guaranteed mint previous rtfkt selected collections otherwise public sale available everyone',
#  'captain',
#  'spoke future',
#  'worthless practical thing even made look cool dont fomo',
#  'metakey rtfkt bonus items owners collectors collections airdropped mintdisc token giving access presale 27th announcing snapshot time drop',
#  'whats job',
#  'rtfkt wins best fashion fyi pronounced artefact yes rtfkt artefact',
#  'time square take pic avatar front nyc location billboards use nftnyc rtfkt chance win clone x',
#  'nyc know itd annoying af dropped time dw',
#  'rtfkt team wont nyc busy final touch clones however rtfkt nyc',
#  'tik tok exclusive eth high sneaker live 50 pairs 0 15 eth come served',
#  'mainly',
#  'ahha recently pushed clones release bc full focus ready need nice website bayc x mayc drop',
#  'even us',
#  'production built boomerverse',
#  'clone x giveaway giving away x10 clone x avatars amazing discord community join enter giveaway channel',
#  'youll get unique files ready use different platforms wish',
#  'giveaway celebrate upcoming clonex avatar drop giving away x10 avatars enter 1 rt tweet 2 follow 3 tag friends x10 winners randomly selected oct 3rd',
#  'iconic metajacket arrived airdropped holders jackets 1 1',
#  'head sick perfect fit',
#  'rtfkt qualified whitelist pinned message discord',
#  'lots killer creator builder team put together ambitious',
#  'rtfkt making avatar drop probably nothing',
#  'keep shoes miss next physical forging events airdrops linked',
#  'based company easiest way invest get',
#  'dont need rtfkt metakeys part selection allowing pre sale public sale open everyone',
#  'avatar coming ready estimate end sept mid october full 3d traits custom modeled kit bashing quality focused high end avatars ready dedicated site info coming',
#  'public sale dutch auction 0 05 price presales rtfkt holders full info launch coming soon',
#  'qualifying havent launched token yet',
#  'jeff staple legendary proud got thanks met',
#  'holders early access everyone',
#  'gm big gm gm warriors',
#  'creator toy drop toy meta alchemist creator price 0 1 eth editions 20 buy',
#  'creator toy drop toy urloc ghale creator price 0 1 eth editions 20 buy',
#  'creator toy drop toy defi demon creator price 0 1 eth editions 20 buy',
#  'drop winners rtfkt toy challenge drop us today 1pm pt time account 20x design 0 1eth',
#  'rtfkt drip expanding weve partnered iconic fashion designs available avatars get limited time meta jacket cyber sneakers fewo shoes free yep',
#  'drip',
#  'rtfkt creator challenge 16 toy challenge place archetype vini participate drop us date tbc',
#  'rtfkt creator challenge 16 toy challenge place urloc ghale erick tosco participate drop us date tbc',
#  'rtfkt creator challenge 16 toy challenge place defi demon justfredrik participate drop us date tbc',
#  'creator challenge 16 announcing winners toy challenge today winners discord cc participate drop us allow access avatar drop',
#  'yes everyone owns fewo world eligible dcl airdrop get contact us get airdrop',
#  'fewo world wallet get contact us airdrop',
#  'get airdrop fewo world contact get',
#  'airdropped wearables fewo world x rtfkt holders',
#  'cybersneaker production prototype owner cybersneaker genesis',
#  'reach irl home nov yeah youll able flex nyc',
#  'shipping nov yep goes according plan',
#  'hey punk recently avail anymore punks sneakers gen 1 generated may time holders redeem physical via forging',
#  'x world series ring auction live bidding winner auction gets physical diamond ring perks',
#  'winner x world series ring receive physical version',
#  'physical sneaker offspring born without cant create physicals later line plan allow holders sell physicals make',
#  'thats partnered stock x sneakers authenticated via system token number inside sneaker future physicals sneakers implementing chips',
#  'focus value attention acting unlocks always updated access keys different experiences physicals',
#  'partnered host secondary market physical sneakers list fewo shoes buy forge',
#  'physicaaaaaalll sneeeaaaaaskkkkeeeeerrrsss',
#  'available fewo shoe',
#  'need rtfkt fewo shoe',
#  'many new punk owners getting lots dm generate gen 1 rtfkt punk sneaker',
#  'attention voxel x sanbox artists looking 2 creators join gang dm us post work bellow work something really crazy cool af us potentially youre dope fun',
#  'coolest couple sure',
#  '1m views tik tok ar fashion conspiracy video best part 5k comments reading',
#  'collab redeem forge days week',
#  'didnt open moment punks sneaker redeem physicals',
#  'punk sneaker though',
#  'got punk sneaker cant take part forging goes live 1pm pt open 1 week rush',
#  'case wasnt clear punks forging event starting today punks sneakers holders physical pair free buy extras 0 25eth want',
#  '12pm pt available 1 week need punk sneaker metamask',
#  'punk forging starts tomorrow 29th 12 00pm pt hold rtfkt punk sneaker claim punks sneakers',
#  'rtfkt merging worlds x used fewo charm redeem iced irl charm 100 grams white gold vs vvs diamonds drop comments jealous',
#  'love see avatars rocking sneakers look dope style shes ready dunes exploration',
#  'going live marketplace check items listed patient released rtfkt x higsnobiety drip',
#  'ok gonna drop marketplace 30min 2pm pt time drip want',
#  'dope legendary fewo world enter draw',
#  'forging ends 28th june free physicals rtfkt x holders redeem physical items please visit website connect wallet difficulties email forging com',
#  'rtfkt drip weekly experiments 001',
#  'welcome hood',
#  'giveaway alert weve teamed giveaway 75 editions notinparis3 tour alien enter follow steps caption',
#  'cool collab exclusive give away coming later today notifs',
#  'congrats artists collectors proud pulled everyone together cool feature auctions awhile well touch sr collectors week airdrop exclusive alien sneaker wearable',
#  '1hr left bid rtfkt x highsnobiety hoverboards support artist unlock access exclusive alien carapace shiny sneaker',
#  'rtfkt hoverboards auctions end today already higher price damien hirst skateboards keep eye hoverboards collectors get exclusive rtfkt alien sneaker wearable',
#  'rtfkt alien carapace shiny sneaker exclusive hoverboards collectors',
#  'paris highsnobiety collab artists 1 1 hoverboards live 0 5 eth reserve includes portrait exclusive rtfkt alien carapace shiny sneaker dcl wearable support fav artists',
#  'introducing meta pigeon og exclusive gift x holders complete forge process rumour pigeon unlock something future',
#  'forging live x visit redeem physicals gift forging assistance join us discord',
#  'celebrate x physical forging 17th giving away meta pigeon 1 retweet 2 join discord giveaway channel extra',
#  'keep use forge physicals future',
#  'forging x physical redemption coming june 17th every comes exclusive physicals get secondary market',
#  'charging merch good energy exclusive fewo world holders',
#  'everyone dead rtfkt team',
#  'drip collector enjoying exclusive denim',
#  'trying find name new architecture game design unit rtfkt ideas',
#  'introducing metakobe designed collaboration legend guy marshall originator behind basketball phenom signature sneaker reimagined era rtfkt available auction exclusively',
#  'creator drop celebrate nzxt creator challenge dropping limited edition winners friday 28th may',
#  'good morning making dope today',
#  '8 believe future fashion driven born communities rtfkt luxury exclusive creators artisans punks community building creating blueprint future fashion know',
#  '7 gen 1 rtfkt exclusive unlocked via punk might play key role access bonuses future build punks world gen 1 holders rewarded',
#  '5 zoom punk yes comes physical sneakers youll able forge june 22nd 1st pair included gen 1 1eth purchase multiple forging extra owners available',
#  '4 unlocks gen1 includes far fw21 rtfkt punks sneakers 1 1 1 pair physicals forge june 22nd vxl rtfkt punks portrait voxel sneakers files',
#  'scheming creating alongside legend guy marshall designer kobe 1s shoe kobebryant wore ever bringing design rtfkt otp design mode',
#  'average sneaker price market fact make physicals potentially 10k unique designs utilities come utilities come future',
#  'anyone getting minting errors punks sneakers wait till tomorrow well look chain clogged af right still sneakers avail 2 weeks thanks much dope support ok getting ready',
#  'unique rtfkt punks sneaker gets 1 1 1 pair physical forge june 22nd vxl portrait 1 1 airdropped later removed double minting ease chain bit voxel sneakers files made punk',
#  'physicals voxel versions',
#  'actually today happy birthday flexing god surfer iconic vape master',
#  'drop comments websites today tonight change game',
#  'good morning let minute silence websites today launch punks site 12pm pt',
#  'long forge 6 weeks youll able redeem physical',
#  'favorite artist long time friend hyped af house mad scientist preparing crazy projects together best space pirate team',
#  'wil',
#  'concept art minted 2077 part special collector clegfx codex',
#  'team sleep office split around 24 7',
#  'oups spoke fast 11eth bid 1 irl 0',
#  'yes long 6 weeks forging event yoj access physical',
#  'yes physicals available redeem 6 weeks holders time',
#  'btw sneakers comes wearables soon layer 2 marketplace opens',
#  'bc fully focused punks site metamask og wanted lower barrier get non crypto sneakerheads jeff fans dw chain trust',
#  '2005 2021 thanks continuing write legend us rtfkt x staple metapigeon drop 12pm pt today',
#  'metapigeon mk x drop date 6th may 2021 12pm pst 3pm est price 2021 editions 100 physical sneakers included come serve',
#  'metapigeon k minus x drop date 6th may 2021 12pm pst 3pm est price 500 physical sneakers included come serve',
#  'metapigeon x price 1 editions 100 drop date 6th may 2021 12pm pst 3pm est come serve',
#  'genius literally keys experiences hyped board',
#  'biggest collab yet rtfkt x kind funding round curated best people world empower future fashion collectibles time build',
#  'yo plugged find bird next chapter continues may 6th drop',
#  'simulation buys piece art history well never know congrats copping legend continuing innovate involve everyone epic moments',
#  'cryptodarth creator discord early days 15yo raw talent based india doesnt stop grind happy hes minted',
#  'oh yes thing course',
#  'may 4th big news may 6th pigeon may 11th punks may 12th sleep bit',
#  'rtfkt featured meanwhile fashion sectors collective jaw fell open virtual sneaker drop crypto brand rtfkt studios teen artist fewocious',
#  'talking luxury bro',
#  'helping 1 1 collectors still trouble getting nifty week till sunday send participation tokens super collector next week final edition numbers ready mint airdrop',
#  '420 give away live till later today meta haze krypto kush enter 1 follow 2 rt tweet 3 comment opensea link favourite winners randomly chosen 23rd april',
#  'oh pretty iconic',
#  'give away 420 krypto kush exclusive sneaker physical',
#  '420 krypto kush giveaway giving away 5 limited edition 420 krypto kush sneaker physicals enter 1 follow 2 rt tweet 3 comment opensea link favourite winners randomly chosen 23rd april',
#  'purchased x sneaker check wallet exclusive wearable airdropped',
#  '420 give away incoming turn notifications 2 sneakers physicals kryto kush meta haze',
#  'extending 1 week still waiting transfer metamask 80 holders redeemed far forging event 1 success confirming shoe sized shipping info everyone week revealing super collector bonus airdropping next week',
#  'forging events different items mechanics attached fewo shoe show forging event attended highly advise forge events especially',
#  'need youll see next week get airdropped following need account final amount minting',
#  'infinite object decentraland wearable bonus super collector',
#  'need fewo shoe use forge redeem goodies',
#  'fewo forging event today still struggling get nifty metamask helping week manually redeem get physical sneakers dope ltd edition holder forge',
#  'good morning everyone especially punk army',
#  'damn got punk army',
#  'rtfkt boxing match course theres robot involved uppercuts drops tomorrow fight comes irl forging good luck',
#  'cool el capitano',
#  'fabricant rtfkt renaixance view upon origins future avatar fashion created sneakers logo exclusive friday lyx lyxe',
#  'rtfkt punks backstory march call biggest fashion designer talking ethos 2hrs later spoke punk idea made choice good may rfkt4punks 14all',
#  'question punks hanging punk things',
#  'need secondary market',
#  'fewo world update fewo shoe wearables shoe owners redeemed redeem till april 18th get sneaker airdropped free decentraland new layer 2 marketplace live enjoy rtfkt',
#  'best big release today ultimate crypto villain artist humble opinion love hes pushing perceptions imagining transformational concepts new medium',
#  'gm week cool videogames fashion april 16th part dope crew future boxing drop april 17th punks news',
#  'super collector bonus unlocked special 3 fewo shoes drip airdropping next week',
#  'wait find bug affecting collectors theres stuff wanted announce part forging event yes every sneaker comes display still fixing apologies show',
#  'looking issue showing even wallet go something else chill everyone able redeem',
#  'yeah fine basically simple fewo shoe redeem physical lots bonus items forging event',
#  'going forge event live 15min leave live 1 week time everyone get metamask redeem understand big thing might technical hurdles well live helping week discord stress',
#  'forging events future theses unlocking different items',
#  'yeah decided bc itll leave time people get wallets etc communicate new type mechanic need leave time realize',
#  'case guys leaving forging 1 week helping 1 1 delays getting metamask',
#  'gm reveal today till forging time event bringing art real world physical craftsmanship theres exclusive access unlock participants super collectors',
#  'mean redeem pair yes',
#  'rare epic legendary custom engraving ltd edition luxury paper sleeve made experts chanel lv special invites paris fewo holders tomorrow 10am pt',
#  'fewo shoe holdrs fewo x rtfkt x ledger',
#  'need fewo shoe',
#  'fewo world bonus shoe holdrs custom ltd edition luxury artist paper sleeve artwork custom engraved nano rare epic custom engraved nano x legendary exclusive forge event 1 secure af beautiful',
#  'winter burn redemption event',
#  'fewo world forging event items update fewo holders tie dye unique tshirts long sleeve made best guys biz real artisan unique long sleeve legendary holders shown',
#  'shown lil leak unveil today fewo shoe holders redeem forge event april 10th',
#  'redeem 10 12th april forging event fewo world redemption events activations around collection future items box free sneakers next time',
#  'fewo shoe shoes already tough stickers yep stickers fewo shoe holders',
#  'fewo shoe holders access redeem physical sneakers lots extra goodies',
#  'need fewo shoe',
#  'buy fewo shoes access forging event redemption',
#  'dont think ever loud crypto villain 2077 villa full pak epic pieces ultimate crypto vilain flex wait see wild cards pulls week gn',
#  'kill thread always start genuine intentions find partner makes better pushes creative boundaries fun make dopest thing come kills lil smart magician threads like loop',
#  'whats forging event forging events limited time events rtfkt holders redeem unlock access forge special items physical collectibles upgrades thanks blueprint',
#  'whats next artist crew members getting sample physical sneaker design artists get approve sample est 6 8 weeks forging event date drip holders happen unlocking access buy ultra ltd editions',
# ...
#  'sold 9 minutes wow thank much amazing community making launch success stay tuned fashion surprise us solana fashion',
#  'public sale live go please please check url everytime lets go final sprint fashion',
#  '1 hour left public sale reminder use official site minting done desktop phone available secondary markets solana',
#  'highest daily trading volume 1 hours getting listed call thank much runfam fashion nftcommunity',
#  'private sale round 2 begins 1 hour reminder use official site minting done desktop phone solana',
#  'live magic eden marketplace minting started listed preferred secondary marketplace partner check swag join runfam',
#  'thanks making easy possible runfam access spacerunners find us already upcoming section starting 12 23',
#  'minting date alert space runners x nba champions collection drops 2 days private sale 12 22 wed 20 00 pt 04 00 utc public sale 12 23 thu 08 00 pt 16 00 utc join discord join private sale mint',
#  'spacerunners x sneaker closed highest bidded auction 20 000 proceeds goes charity fight bullying extremely happy support using good always top priority',
#  'congrats ko win look forward 1 kind boxing sneakers auctioned jake paul charity fundraiser tomorrow proceeds go fight bullying fashion',
#  'jake drop party fight back bullying glorious',
#  'exciting times spacerunners thanks everyone joining us 100k celebration twitter space discord hangout yesterday extremely happy building fashion next step mint nftcommunity',
#  'extremely excited see leading businesses like entering fashion space however engineering solid minting process building community quite difficult always help please feel free reach',
#  'join spacerunners team twitter spaces hangout fashion friday dec 17th 12pm pt 3pm et giving away 10 whitelist spots set reminder event nftcommunity solana fashionnft',
#  'come chat us spacerunners fashion discord starting today 2pmet 11ampt well hosting voice discussions hangout room runfam join chat get chance whitelisted',
#  'excited featured leading online destination fashion streetwear build fashion bring different cultures identities styles thoughts fashion read solana',
#  'space runners proud partner help combat bullying donating fully customized boxing shoe auctioned proceeds going charity read boxing bullies auction',
#  'hey runfam exciting updates sneak peek multi chain fashionnft marketplace designed items try ar social media filters upgrade traits mentioned fashion',
#  'spacerunners runfam us fashion',
#  'nike acquiring rtfkt today another signal fashion beginning proud early leaders space strong blockchain native team nba champions collection coming soon',
#  'nba champions sneaker collection dropping soon extremely excited share minting details including 3 sprints supported wallets whitelisting discounts rarity calculations allocations nftcommunity',
#  'hit 80k twitter followers 2 days ago 70k runfam growing record pace incredibly thankful support nba champions collection dropping soon join discord get whitelisted',
#  'runfam happen talented meme creators spacerunners meme contest starts rules tweet best sr memes tag 3 friends join discord rewards 1st 500 2nd 300 3rd 100 nftartist',
#  'fashionable',
#  'mind blowing growth great community weve hit 70k followers twitter build digital fashion community community endless thanks lt digital hugs gt fashion',
#  'delighted share space runners featured top 5 upcoming drops check full article fashion',
#  'thrilled share latest article published read fashion rising space runners leading trend fashion',
#  'discord activity race community continues grow incredible rate wed like reward supporting active members discord rewards daily 50 weekly 250 join discord get started nba crypto',
#  'talent alert wow support love coming community leave us speechless big thank talented artist runfam helping us bring sr around world literally growing strong together fashion',
#  'gone days becoming fashion icon physical world redefines fashion extremely happy featured great start great week',
#  'giving shoutout sr may want catch fashion',
#  'hit 60k followers twitter grateful supportive community behind us endless thanks next week full extremely exciting news whos ready nftcommunity',
#  'looking runbassadors join runfam continue build perks include auto join whitelist collaborate exclusive discord flair 100 spots dm us apply join discord',
#  '20 000 giveaway winners 1 2 3 4 contact shortly twitter dm please make sure message coming aware scammers growing fast strong congrats',
#  'option e metakicks',
#  'runners bring fashion vr experiences let continue building',
#  'welcome runnerfamily extremely excited shape future fashion family expands',
#  'metafashion installing complete fashion',
#  'kyle kuzma sneaker launching mid december join whitelist spacerunners',
#  'excited nba star onboard along nick young kyle kuzma launching basketball themed sneaker collection collaboration spacerunners stay tuned getting started metashoes',
#  'hello runners thrilled featured read partnership biggest stars nba right spacerunners',
#  'digital apparel brand metaverses solana wagmi',
#  'hey nftcommunity building apparel ecosystem wonder ama session today meet us 13 00 14 00 est',
#  'digital fashion brand metaverses space runners kyle kuzma partnership 30m initial valuation funded ankr foundation service brands celebs site marketplace visual explorer wear ar feature run token build wear2earn dao',
#  'check apparel brand space runners design launch digitally wearable collaboration celebrities brands nftcommunity',
#  '4 exclusive tools features beyond unique designs space runners come exquisite features wear using ar social media filters embedded metaverses explorer site marketplace trade rent run token defi dao',
#  '3 partnership celebrities brands dedicated bring celebrities brands exceptional designers digital communities together order create interactive experience check kyle kuzma partnership',
#  '2 solid roadmap towards wear2earn ecosystem presale launch important comes launch critical determined roadmap achieve ultimate goal becoming biggest digital clothing brand feel free check',
#  '1 appeal digital experiences games taken beyond design giving utility however 1 mostly game crypto audience 2 poor gameplay aim utility experience broad visibility time',
#  '3 500 active projects many avatars plenty robots animals lands cars creatures care another thread time',
#  'next big things apparel nba fashion',
#  'vision new place interact humans bots play games conduct business socialize shop excited metashoes',
#  'extremely happy proud see space runners getting featured love support runners way go kuzma',
#  'thrilled featured read partnership biggest stars nba right metashoes spacerunners',
#  'lets start week listing space runners x kyle kuzma launch listed nftcommunity',
#  'weve hit 20 000 twitter followers runners excellent start exciting week metashoes 1 apparel brand',
#  'gaining fame 15 seconds early developers ecosystem feel responsibility innovating space nftcommunity',
#  'art gt arts sure make art functional without compromising beauty allow art become fragile objects rather make open interaction cumulative evolution',
#  'digital sneakers available soon nftcommunity',
#  'probably love digital sneakers nftcommunity',
#  'night kyle kuzma official sneaker drop soon nftcommunity',
#  'spacerunner reach marketplace grab pair brokenshoe comment answers nftcollector fridayfun',
#  'excited celebrity collaborations nba star kyle kuzma partnering spacerunners launch shoe brand stay tuned exciting partnerships ahead nftcollection celebrity',
#  'seen digital sneaker wear metaverses games social media partners announced soon check',
#  'kick digital kickers check nftcollector',
#  'believe future people socialize earn play dress simply exist digital environment nonfungible fashionable explore us spacerunners digitalasset',
#  'collection spacerunners done collaboration top celebrities stars broken shoe brings iconic pairs real life digital join whitelist nftcommunity nftartist celebrity',
#  'ar wallets wear runners pose social media filters site marketplace integration games metaverses virtual events run token create weartoearn ecosystem service brands',
#  'wearable digital sneakers arrived solana 30m initial valuation 1 7k discord members 2 6k twitter followers 1 designed reddits artists 2 signed nba partners mint presale lifetime loyalty reward 0 5 commission',
#  'ghosts wanna fun spacerunners shoes spot runners shoes halloween happyhalloween2021',
#  'tag favourite artists',
#  'giveaway winners 1 2 3 contact shortly twitter dm please make sure message coming aware scammers officially holders runner congrats',
#  'digitally wearable sneakers mint presale 0 5 lifetime royalty check',
#  'trade ar wallets wear runners pose social media filters site marketplace integration games metaverses virtual events run token create weartoearn ecosystem service brands',
#  'wearable digital sneakers arrived solana 30m initial valuation 1 7k discord members 2 6k twitter followers 1 designed reddits artists 2 signed nba partners mint presale lifetime loyalty reward 0 5 commission',
#  'gm twitter community expanding every second fastest growing discord communities ever reached almost 4k members less 3 days launching discord celebrate giving away 3 runner',
#  'amazing support trending twitter designing digital sneakers metaverses probably nothing',
#  'space runners giveaway giving away x3 runners rules like retweet post tag 2 spacerunners friends 3 random winners chosen ends oct 26th 15 00 utc',
#  'building digitally wearable sneakers online spaces like metaverses games social media 30m initial valuation designed reddits artists 2 signed nba partners announced ar wallets social media filters service brands',
#  'building digitally wearable sneakers online spaces like metaverses games social media 30m initial valuation designed reddits artists 2 signed nba partners announced ar wallets social media filters service brands',
#  'mention favourite sneaker brand nike adidas reebok puma',
#  'x 5 x wl spots giveaway follow rt tag 3 friends join win cash nftgiveaway utilitynft metatriads bluechipnft passiveincome wlgiveaways nftcollection',
#  'shibabeast x meta triads giveaway 5 wl shibabeast 5 wl meta triads 1 follow 2 like rt 3 tag 5 frens',
#  'news metatriads benzinga meta triads launching high utility marketplace fashion apparel read full article metaversenft nftgiveaway nftcommunity nftgiveaways',
#  'needs mods ai force wanna win wl spot 1 follow rt tag 3 friends 2 join discord ends 48 hours metatriads nftgiveaway nftart wlgiveaways whitelist nftcommunity nftcollector nftdrop',
#  'world watching coingape news metatriads nftcollection pressrelease nftcommunity nftdrop nftcommunity nftgiveaway',
#  'look came swim us 5 bl spots whalamazing blues enter 1 follow 2 rt 3 tag 3 cyber whales know 4 join blues discord ends 24h wlgiveaways nftgiveaway',
#  'meta triads x braindom games prizes 3 wl spots braindom games rules 1 follow 2 tag 2 lovers tag extra entry 3 like retweet post 48 hours nftgiveaway metatriads whitelist wlgiveaway',
#  'world watching published press release meta triads meta triads launches high utility uniting 3 worlds read full article',
#  'newsbtc posted metatriads major fashion brands landing projects proud excited see name next azuki clonex read full article',
#  'get rekt meatbags join metatriads discord get perks ar physical world nftcommunity nftart',
#  'race hybrid fav animal schr dingers cat name hybrid win wl spot rules 1 quote tweet best name like tweet 2 join discord ends 24 hours',
#  'yay got butterflies worry process super smooth tested many times lol',
#  'thank',
#  'want another sneak peek minted feature limited edition handmade accessories get heart racing artwork created 200 hand drawings international artist previous contestant dayoung kim',
#  'excited announce partnered mint collection premium launchpad mint page og list presale 2 28 rainbow list presale 3 2 public mint 3 3 getminting nftcommmunity mint mvnnft',
#  'thank',
#  '10 days presale mint screaming inside mavion og list thank wait see mint lfg countdown mint mvnnft mavionworld',
#  'happy',
#  'meet artist dayoung kim mavion feature 200 hand drawn features dayoung kim international illustrator fashion designer dayoung fashion label former designer runway nftartist art womeninnfts mavion mvnnft',
#  'thank',
#  '5 creators female talked kick event fired ever launch start boost number lfg ladies',
#  'lets welcome cardano',
#  'need holder least 1 soho kids 1 retrosound 26th march take snapshot check wallets eligible must delisted wallet join retrosound discord',
#  'soho kids x retrosound collab airdrop worked friends retrosound created awesome cassette going airdrop holders projects participate',
#  'yes listed api show us real owners',
#  'lets start soho follow soho chain post soho kids lets follow',
#  'bots bounced',
#  'official policy id soho kids c9c4d9e7fdec835f0cb95b15348509872322a888a9fac4f64dfef0ec hey',
#  'thank shoutout',
#  'much love opportunity heres chance get hands soho kids',
#  'quick fyi test models want relate much possible want represent large amount traits skin colors works',
#  'hey everyone soho kids pfp based collection focuses fashion streetwear haute couture streets soho cardanocommunity',
#  'sooo lit season 1 1297 1 1 co created cure hydrangea nehalennia dropsuit studio mintingmoment',
#  'puff sleeve meta suit represents asserts power charming presence wearer choice strong twisted metallic textures high rises puff sleeve makes like magic flares bottom available indieweb3fashion',
#  'feel superior power goddess outfit digitalax indieweb3fashion',
#  'taking indiancultures traditions wearing customized outfit called lehenga indian culture bride wears wedding always jeffy looks stunning drop comments digitalfashion virtualreality',
#  'outline explain key technologies projects influential fashion across digital clothing mixed reality gaming beyond',
#  'literally friday',
#  'drop bi moon love bi moon love explores magical tale love longing phobos deimos available 1 1 nftdrop nftcommumity nftcollectors nftcollector womeninnfts',
#  'slight presence lights whole universe whole world admired softness heart longs love meet thousands years things get magical drop nftdrop nftcommunitiy nftcollectors',
#  'mars moon seen tough times softness stays lover longing meet thousands years know phobos bi moon love drop soon nftcollector nftcommunity',
#  'made give superpowers aspire gain cardinal cosmos bts cardinal meta suit available exclusively get nftcollectors nftcommunity nftdrop digitalfashion meta ethereumnfts',
#  'hey seems great apply',
#  'escaping new reality away current reverie get ready see glimpse getaway mars nftcommunity nftartist cryptoart virtualfashion futureoffashion 3dfashion itsclo3d',
#  'merry christmas everyone merrychristmas nftart bells meta2022',
#  'came sneak peeks stylists special selection 8 days chance super beautiful ladies excited working hard looking forward announcing honorary agreements valuable artists',
#  'like thank esteemed artist selay karasu accepting offer honorary member family beautiful glad us even excited march 8',
#  'happy show honorary sneak peek dear artist idil dursun honorary member family special 1 1 design sent directly jarvins wallet march 8th love give us strength',
#  'like emphasize goal san coiffure founder yusuf yalmanci wanted achieve creating sc ladies digitalization process well hairdresser well even hair peoples avatars',
#  'sc biggest womens hairdressing chains serves whole world especially europe dubai katar abu dhabi company hosts average 50000 women per month officially started digitalization process established sc ladies',
#  'different unique san coiffure serving 8 years beautification women turkey world motto decided reflect unique hair made based slogan uses sector',
#  'sure collection already valuable pieces series want meet worlds stylist leave link',
#  'gm fashion fam hope flippin awesome digitalfashion',
#  'joker fits logic well',
#  ...]

# %%
media_results_df = pd.DataFrame()

for x in range(len(media_text_list)):
    dict = {'Tweet': media_text_list[x],'Processed': clean_tweet(media_text_list[x])}
    media_results_df = media_results_df.append(dict, ignore_index = True)

media_results_df.to_csv('processed twitter data/media_results.csv', index=False)
print('done')
media_results_df
# Out:
# C:\Users\banna\AppData\Local\Temp/ipykernel_92256/767197126.py:13: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   if type(tweet) == np.float:
# done
#                                                   Tweet  \
# 0     Metaverse launches have been frequent in the l...
# 1     Metaverse launches have been frequent in the l...
# 2     Positioned as a physical metaverse influencer ...
# 3     Marketers discussed ways into the metaverse, a...
# 4     Positioned as a physical metaverse influencer ...
# ...                                                 ...
# 1034  Poly Auction Hong Kong is joining hands with d...
# 1035  The Hong Kong director celebrates the 30th ann...
# 1036  Poly Auction Hong Kong is joining hands with d...
# 1037  The Hong Kong director celebrates the 30th ann...
# 1038  Luxury luggage brand, Rimowa, on their first-e...
#
#                                               Processed
# 0     launches frequent brands including gucci adida...
# 1     launches frequent brands like launching accord...
# 2     positioned physical influencer creator hub 1 2...
# 3     marketers discussed ways among topics digiday ...
# 4     positioned physical influencer creator hub 1 2...
# ...                                                 ...
# 1034  poly auction hong kong joining hands digital a...
# 1035  hong kong director celebrates 30th anniversary...
# 1036  poly auction hong kong joining hands digital a...
# 1037  hong kong director celebrates 30th anniversary...
# 1038  luxury luggage brand rimowa ever collection de...
#
# [1039 rows x 2 columns]

# %%
creator_results_df = pd.DataFrame()

for x in range(len(creator_text_list)):
    dict = {'Tweet': creator_text_list[x],'Processed': clean_tweet(creator_text_list[x])}
    creator_results_df = creator_results_df.append(dict, ignore_index = True)

creator_results_df.to_csv('processed twitter data/creator_results.csv', index=False)
print('done')
creator_results_df
# Out:
# C:\Users\banna\AppData\Local\Temp/ipykernel_92256/767197126.py:13: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   if type(tweet) == np.float:
# done
#                                                   Tweet  \
# 0     Inspired by a profound desire to explore new p...
# 1     Vault aims to embrace Web3 by delving deep int...
# 2     For a preview of our roadmap: #SUPERGUCCI will...
# 3     gm, the House is delighted to announce its lau...
# 4     @adidasoriginals Welcome Fren, 2022 is the yea...
# ...                                                 ...
# 3344  @AB_solo You can try again tomorrow… or the ne...
# 3345  @KaddouraHoussam The made-to-order Rogue bag i...
# 3346  @Thatjpeg_ Our first NFT will be available at ...
# 3347  @uuuulllii We’re offering a limited quantity o...
# 3348  ✨ Why we’re entering the NFT space: to mark th...
#
#                                               Processed
# 0     inspired profound desire explore new playgroun...
# 1     vault aims embrace web3 delving deep creation ...
# 2     preview roadmap supergucci vault part part dro...
# 3     gm house delighted announce launch experimenta...
# 4                      welcome fren 2022 see guccivault
# ...                                                 ...
# 3344             try tomorrow next drops continue 12 24
# 3345           made order rogue bag available us owners
# 3346                       available 12 p est get ready
# 3347  offering limited quantity followers free dec 1...
# 3348  entering space mark end 80th anniversary speci...
#
# [3349 rows x 2 columns]
