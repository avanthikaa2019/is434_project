# %%
import pandas as pd

# %%
all_topics_labelled = pd.read_csv('topics_labelled_all.csv')

# %%
all_topics_labelled
# Out:
#       Document_No  Dominant_Topic  Topic_Perc_Contrib  \
# 0               0             0.0              0.3754
# 1               1             0.0              0.3928
# 2               2             3.0              0.3671
# 3               3             3.0              0.3252
# 4               4             3.0              0.3499
# ...           ...             ...                 ...
# 4377         4377             0.0              0.3180
# 4378         4378             2.0              0.3340
# 4379         4379             1.0              0.3005
# 4380         4380             1.0              0.3707
# 4381         4381             3.0              0.4619
#
#                                                Keywords  \
# 0     drop, fashion, love, world, big, new, time, be...
# 1     drop, fashion, love, world, big, new, time, be...
# 2     collection, physical, digitalax, sell, owner, ...
# 3     collection, physical, digitalax, sell, owner, ...
# ...

# %%
all_topics_labelled.drop(columns=['Text'],inplace = True)

# %%
all_topics_labelled
# Out:
#       Document_No  Dominant_Topic  Topic_Perc_Contrib  \
# 0               0             0.0              0.3754
# 1               1             0.0              0.3928
# 2               2             3.0              0.3671
# 3               3             3.0              0.3252
# 4               4             3.0              0.3499
# ...           ...             ...                 ...
# 4377         4377             0.0              0.3180
# 4378         4378             2.0              0.3340
# 4379         4379             1.0              0.3005
# 4380         4380             1.0              0.3707
# 4381         4381             3.0              0.4619
#
#                                                Keywords
# 0     drop, fashion, love, world, big, new, time, be...
# 1     drop, fashion, love, world, big, new, time, be...
# 2     collection, physical, digitalax, sell, owner, ...
# 3     collection, physical, digitalax, sell, owner, ...
# ...

# %%
new_all_df = pd.read_csv('new_all_df.csv')

# %%
new_all_df
# Out:
#                                                   Tweet  \
# 0     Metaverse launches have been frequent in the l...
# 1     Metaverse launches have been frequent in the l...
# 2     Positioned as a physical metaverse influencer ...
# 3     Marketers discussed ways into the metaverse, a...
# 4     Positioned as a physical metaverse influencer ...
# ...                                                 ...
# 4377  @AB_solo You can try again tomorrow… or the ne...
# 4378  @KaddouraHoussam The made-to-order Rogue bag i...
# 4379  @Thatjpeg_ Our first NFT will be available at ...
# 4380  @uuuulllii We’re offering a limited quantity o...
# 4381  ✨ Why we’re entering the NFT space: to mark th...
#
#                                               Processed  \
# 0     launches frequent brands including gucci adida...
# 1     launches frequent brands like launching accord...
# 2     positioned physical influencer creator hub 1 2...
# 3     marketers discussed ways among topics digiday ...
# ...

# %%
topics_all_df = pd.concat([new_all_df,all_topics_labelled],axis=1)
topics_all_df
# Out:
#                                                   Tweet  \
# 0     Metaverse launches have been frequent in the l...
# 1     Metaverse launches have been frequent in the l...
# 2     Positioned as a physical metaverse influencer ...
# 3     Marketers discussed ways into the metaverse, a...
# 4     Positioned as a physical metaverse influencer ...
# ...                                                 ...
# 4377  @AB_solo You can try again tomorrow… or the ne...
# 4378  @KaddouraHoussam The made-to-order Rogue bag i...
# 4379  @Thatjpeg_ Our first NFT will be available at ...
# 4380  @uuuulllii We’re offering a limited quantity o...
# 4381  ✨ Why we’re entering the NFT space: to mark th...
#
#                                               Processed  \
# 0     launches frequent brands including gucci adida...
# 1     launches frequent brands like launching accord...
# 2     positioned physical influencer creator hub 1 2...
# 3     marketers discussed ways among topics digiday ...
# ...

# %%
topics_all_df.to_csv('ALL_TOPICS_LABELLED_FINAL.csv', index=False)

# %%
pd.set_option('display.max_colwidth', None)
df1 = topics_all_df[topics_all_df['Dominant_Topic']== 0.0].sort_values(by=['Topic_Perc_Contrib'], ascending=False).head(15)[['Tweet','Topic_Perc_Contrib']]
df2 = topics_all_df[topics_all_df['Dominant_Topic']== 1.0].sort_values(by=['Topic_Perc_Contrib'], ascending=False).head(15)[['Tweet','Topic_Perc_Contrib']]
df3 = topics_all_df[topics_all_df['Dominant_Topic']== 2.0].sort_values(by=['Topic_Perc_Contrib'], ascending=False).head(15)[['Tweet','Topic_Perc_Contrib']]
df4 = topics_all_df[topics_all_df['Dominant_Topic']== 3.0].sort_values(by=['Topic_Perc_Contrib'], ascending=False).head(15)[['Tweet','Topic_Perc_Contrib']]

# %%
df1
# Out:
#                                                                                                                                                                                                                                                                                                                                 Tweet  \
# 150                                                               The fashion exec’s guide to the metaverse. The #metaverse is here. We outline and explain the key technologies and projects most influential to fashion across digital clothing, mixed reality, gaming, #NFTs and beyond.\n\nFind out more: https://t.co/Vcrnp8TwS9
# 260                                                                              The fashion exec’s guide to the metaverse. \nThe metaverse is here. We outline and explain the key technologies and projects most influential to fashion across digital clothing, mixed reality, gaming, NFTs and beyond.\n\nhttps://t.co/Vcrnp8BVtz
# ...

# %%
df2
# Out:
#                                                                                                                                                                                                                                                                                                                 Tweet  \
# 1075   2/\nThe Lion Crown. Inspired by the Venetian coat of arms, this incredible piece took hundreds of hours to create by hand and features 16 rubies (92+ total carats) and 9 rose-cut diamonds (1.5+ total carats). NFT + digital wearable + physical crown + 2-year experiential access. https://t.co/tnIHFp6oce
# 1101  11/\nThe Lion Crown. Inspired by the Venetian coat of arms, this incredible piece took hundreds of hours to create by hand and features 16 rubies (92+ total carats) and 9 rose-cut diamonds (1.5+ total carats). NFT + digital wearable + physical crown + 2-year experiential access. https://t.co/8slS1nFjd6
# ...

# %%
df3
# Out:
#                                                                                                                                                                                                                                                     Tweet  \
# 632         Dutch DJ Don Diablo is building a massive NFT — literally. "What if you could stand inside an NFT, literally? That hasn’t been done before," says Diablo, who will put the project up for private sale with Sotheby’s https://t.co/6Y81xXXtJK
# 633         Dutch DJ Don Diablo is building a massive NFT — literally. "What if you could stand inside an NFT, literally? That hasn’t been done before," says Diablo, who will put the project up for private sale with Sotheby’s https://t.co/KoTuR8dbaJ
# ...

# %%
topics_all_df['Dominant_Topic'].value_counts(normalize=True)
# Out:
# 3.0    0.434733
# 1.0    0.216796
# 0.0    0.204245
# 2.0    0.144226
# Name: Dominant_Topic, dtype: float64

# %%
df4
# Out:
#                                                                                                                                                                                                                                                                                                                     Tweet  \
# 1279     reminder to be ULTRA careful with dms on discord 🚨\n\nWe will NEVER dm you, block dms from common servers in your discord settings \n\nThis is usefull for everyone in the NFT Space, do it to avoid scams, too many people getting their NFT’s stolen or buying fake nfts everyday here https://t.co/lN1N6kaxtx
# 1275  Space Pod Airdrop  \nThe first item of the roadmap will be airdropped by the end of the month. Your Clones very own @oncyber_io  SPACE POD 🚀 \n\n1 Clone=1 Space Pod NFT\nClones will be airdropped their Space Pods.\nUnrevealed Vials will have to pay a gas fee to claim their space pod https://t.co/giYN84kVMW
# ...

# %%
general_topics_labelled = pd.read_csv('topics_labelled_general.csv')
general_topics_labelled
# Out:
#        Document_No  Dominant_Topic  Topic_Perc_Contrib  \
# 0                0             2.0              0.5289
# 1                1             2.0              0.4445
# 2                2             2.0              0.4439
# 3                3             0.0              0.4597
# 4                4             1.0              0.3243
# ...            ...             ...                 ...
# 24939        24939             2.0              0.4282
# 24940        24940             0.0              0.3743
# 24941        24941             2.0              0.2981
# 24942        24942             2.0              0.3464
# 24943        24943             0.0              0.3565
#
#                                                                                     Keywords  \
# 0             digital, brand, new, designer, blockchain, game, virtual, future, launch, sell
# 1             digital, brand, new, designer, blockchain, game, virtual, future, launch, sell
# ...

# %%
new_general_df = pd.read_csv('new_general_df.csv')

# %%
general_topics_labelled.drop(columns=['Text'],inplace = True)

# %%
topics_general_df = pd.concat([new_general_df,general_topics_labelled],axis=1)
topics_general_df
# Out:
#                                                                                                                                                                                                                                                                                                                    Tweet  \
# 0                                “Digital fashion and virtual spaces are expanding beyond games; Roblox doesn’t even identify as a gaming platform. At the upcoming Metaverse Fashion Week, many brands will be selling both digital and physical versions of designs, while Gucci and Adidas ar…https://t.co/XEPn6d1B9T
# 1                                                                                                                                            ⚡Shiba Inu To Launch New NFT Fashion Collection With British Designer John Richmond  🥻🐶 #NFT #SHIB #shibarmy #cryptocurrency #CryptoNews #Crypto ⚡\nhttps://t.co/DX5JzxXvZd
# ...

# %%
topics_general_df['Dominant_Topic'].value_counts(normalize=True)
# Out:
# 0.0    0.607842
# 2.0    0.237211
# 1.0    0.145366
# 3.0    0.009581
# Name: Dominant_Topic, dtype: float64

# %%
df_g_sent = pd.read_csv('../df_g_sent.csv')

# %%
df_g_sent
# Out:
#        Unnamed: 0 Label  Compound  \
# 0               0   neu    0.0000
# 1               1   neu    0.0000
# 2               2   neu    0.0000
# 3               3   neu    0.0000
# 4               4   neu   -0.4019
# ...           ...   ...       ...
# 24939       24939   neu    0.0000
# 24940       24940   neu    0.0000
# 24941       24941   neu    0.0000
# 24942       24942   neu    0.3400
# 24943       24943   neu    0.0000
#
#                                                                                                                                                                       Process  \
# 0           digital virtual spaces expanding beyond games roblox identify gaming platform upcoming week many brands selling digital physical versions designs gucci adidas ar
# 1                                                               shiba inu launch new collection british designer john richmond shib shibarmy cryptocurrency cryptonews crypto
# ...

# %%
df_g_sent.drop(columns=['Unnamed: 0'],inplace = True)

# %%
combi_general_df = pd.concat([topics_general_df,df_g_sent[['Label','Compound','Likes','Retweets','Replies','Quotes']]],axis=1)

# %%
combi_general_df
# Out:
#                                                                                                                                                                                                                                                                                                                    Tweet  \
# 0                                “Digital fashion and virtual spaces are expanding beyond games; Roblox doesn’t even identify as a gaming platform. At the upcoming Metaverse Fashion Week, many brands will be selling both digital and physical versions of designs, while Gucci and Adidas ar…https://t.co/XEPn6d1B9T
# 1                                                                                                                                            ⚡Shiba Inu To Launch New NFT Fashion Collection With British Designer John Richmond  🥻🐶 #NFT #SHIB #shibarmy #cryptocurrency #CryptoNews #Crypto ⚡\nhttps://t.co/DX5JzxXvZd
# ...

# %%
combi_general_df.to_csv('GENERAL_TOPICS_LABELLED_FINAL.csv', index=False)

# %%
df_g_sent[['Label','Compound','Likes','Retweets','Replies','Quotes']]
# Out:
#       Label  Compound  Likes  Retweets  Replies  Quotes
# 0       neu    0.0000    0.0       0.0      0.0     0.0
# 1       neu    0.0000    6.0       0.0      0.0     0.0
# 2       neu    0.0000    0.0       0.0      0.0     0.0
# 3       neu    0.0000    9.0       3.0      0.0     3.0
# 4       neu   -0.4019    9.0       2.0      0.0     0.0
# ...     ...       ...    ...       ...      ...     ...
# 24939   neu    0.0000    0.0       0.0      0.0     0.0
# 24940   neu    0.0000    3.0       0.0      0.0     0.0
# 24941   neu    0.0000    0.0       0.0      0.0     0.0
# 24942   neu    0.3400    6.0       1.0      0.0     0.0
# 24943   neu    0.0000    1.0       0.0      1.0     0.0
#
# [24944 rows x 6 columns]

# %%
gf1 = combi_general_df[combi_general_df['Dominant_Topic']== 0.0].sort_values(by=['Topic_Perc_Contrib'], ascending=False).head(15)[['Tweet','Topic_Perc_Contrib']]
gf2 = combi_general_df[combi_general_df['Dominant_Topic']== 1.0].sort_values(by=['Topic_Perc_Contrib'], ascending=False).head(30)[['Tweet','Topic_Perc_Contrib']].drop_duplicates(subset=['Topic_Perc_Contrib'])
gf3 = combi_general_df[combi_general_df['Dominant_Topic']== 2.0].sort_values(by=['Topic_Perc_Contrib'], ascending=False).head(15)[['Tweet','Topic_Perc_Contrib']]
gf4 = combi_general_df[combi_general_df['Dominant_Topic']== 3.0].sort_values(by=['Topic_Perc_Contrib'], ascending=False).head(15)[['Tweet','Topic_Perc_Contrib']]

# %%
gf1
# Out:
#                                                                                                                                                                                                                                                                                                                         Tweet  \
# 16969                     HOME.MAGAZINE\nCAR.MAGAZINE\nMEN.MAGAZINE\nWOMEN.MAGAZINE + 1 \nSPORTS.MAGAZINE + 1\nTEEN.MAGAZINE \nBUSINESS.MAGAZINE\nHEALTH.MAGAZINE\nFASHION.MAGAZINE\nLIFESTYLE.MAGAZINE\nTRAVEL.MAGAZINE\nMARKETING.MAGAZINE\nONLINE.MAGAZINE\nDIGITAL.MAGAZINE\nTENNIS.MAGAZINE\nGOLF.MAGAZINE\nNFT.MAGAZINE
# 19182         "Nure-onna / Love yourself" is part of my photographic series "my Demons" 👹\nAvailable on @withfoundation #NFT \nLink in Bio.\nI will give this animation to the collector as well ⚠️🤝🔥\n#nftcollectors  #nftcommunity #art #japanese #red #woman #fashion #portrait #foundation #demon https://t.co/kiAFiOD5Ik
# ...

# %%
gf2
# Out:
#                                                                                                                                                                                                                                                                                                                            Tweet  \
# 19498                             Bored Ape Yacht Club = \nBored APE = \nBAPE.\n\nIts  BAPE + Supreme + Anti Social Social Club in an NFT project. \n\nThe fashion reference has been sitting in everyones face this whole time but no one really seems to be picking it up. Its a cultural flex thing fam. Streetwear bois know
# 18170              License to kill. History of violence. I could be speaking to my own reflection\nBond collection of 50 NFT tshirts\nhttps://t.co/Mbz9lGEtMR #bond #love #jamesbond #danielcraig #notimetodie #family #nft #nftart #art #digitalart #tshirts #tshirt #fashion #tshirtdesign #collection https://t.co/9iGoacPEuH
# ...

# %%
gf3
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                  Tweet  \
# 366                                                                                                                                          Fashion startup 🚀 raising a Seed round out of !\n\n 1-Line: Digital fashion house for 3D, AR and NFT assets, for Metaverse brands\n\nInvestors connect at 👉🏽 https://t.co/hrIqaTCOEn\n\n#startup #investors #founder #vc #angels #Fashion
# ...

# %%
gf4
# Out:
#                                                                                                                                                                                                                                                                                                                          Tweet  \
# 13903                             Extinct com, NESI com, CrowdFunds com, Mediar com, Hardway com, Fashions org, SERJ com &amp; LBC co: Undervalued GoDaddy Domain Auction Recap Dec 14, 2021 #domains #startups #investing #digitalmarketing #CBD #StockMarket #realestate #app #web #NFTs #metaverse\nhttps://t.co/k0nQwfnkog
# 8588            Chiefy, do you know what you’re doing?💉😵‍💫🤮☠️\n-\nnypd rcmp sheriff guard xrp ranger chef baker taxi nft tesla cardano ethereum litecoin realtor dentist nba nhl nfl axie silver stocks gold patriots Sox prepper bts raptors Canucks oilers lgbtq pets fashion mavericks rugby beeple https://t.co/afDg6bUOCe
# ...

# %%
compiler_topics_labelled = pd.read_csv('topics_labelled_compiler.csv')
compiler_topics_labelled
# Out:
#     Document_No  Dominant_Topic  Topic_Perc_Contrib  \
# 0             0             0.0              0.9895
# 1             1             0.0              0.9779
# 2             2             1.0              0.9693
# 3             3             2.0              0.9914
# 4             4             1.0              0.9895
# 5             5             2.0              0.9909
# 6             6             0.0              0.9779
# 7             7             0.0              0.6548
# 8             8             2.0              0.9898
# 9             9             2.0              0.9925
# 10           10             2.0              0.9904
# 11           11             1.0              0.5074
# 12           12             1.0              0.9549
# 13           13             1.0              0.9829
# 14           14             2.0              0.9918
# 15           15             2.0              0.9799
# 16           16             2.0              0.9918
# ...

# %%
compiler_topics_labelled['Dominant_Topic'].value_counts(normalize=True)
# Out:
# 0.0    0.413793
# 2.0    0.327586
# 1.0    0.258621
# Name: Dominant_Topic, dtype: float64

# %%
df_c_sent = pd.read_csv('../df_c_sent.csv')

# %%
df_c_sent
# Out:
#     Unnamed: 0 Label  Compound  \
# 0            0   neu    0.5994
# 1            1   pos    0.5423
# 2            2   neu    0.3612
# 3            3   neu    0.9186
# 4            4   neu    0.7964
# 5            5   pos    0.9423
# 6            6   neu    0.6249
# 7            7   neu    0.7003
# 8            8   neu    0.9432
# 9            9   neu    0.9638
# 10          10   neu    0.7579
# 11          11   pos    0.8442
# 12          12   pos    0.7845
# 13          13   neu    0.7096
# 14          14   neu    0.9337
# 15          15   neu    0.5267
# 16          16   pos    0.9485
# 17          17   pos    0.9485
# 18          18   pos    0.9337
# 19          19   neu    0.8720
# 20          20   neu    0.9349
# 21          21   neu    0.2960
# 22          22   neu    0.6901
# 23          23   pos    0.9565
# 24          24   pos    0.8934
# 25          25   pos    0.9595
# 26          26   neu    0.8402
# 27          27   neu    0.5859
# 28          28   pos    0.9231
# ...

# %%
df_c_sent.drop(columns=['Unnamed: 0'],inplace = True)

# %%
combi_comp_df = pd.concat([compiler_topics_labelled,df_c_sent[['Label','Compound','Likes','Retweets','Replies','Quotes']]],axis=1)

# %%
combi_comp_df
# Out:
#     Document_No  Dominant_Topic  Topic_Perc_Contrib  \
# 0             0             0.0              0.9895
# 1             1             0.0              0.9779
# 2             2             1.0              0.9693
# 3             3             2.0              0.9914
# 4             4             1.0              0.9895
# 5             5             2.0              0.9909
# 6             6             0.0              0.9779
# 7             7             0.0              0.6548
# 8             8             2.0              0.9898
# 9             9             2.0              0.9925
# 10           10             2.0              0.9904
# 11           11             1.0              0.5074
# 12           12             1.0              0.9549
# 13           13             1.0              0.9829
# 14           14             2.0              0.9918
# 15           15             2.0              0.9799
# 16           16             2.0              0.9918
# ...

# %%
combi_comp_df.to_csv('COMPILER_TOPICS_LABELLED_FINAL.csv', index=False)

# %%
df_c_sent[['Label','Compound','Likes','Retweets','Replies','Quotes']]
# Out:
#    Label  Compound  Likes  Retweets  Replies  Quotes
# 0    neu    0.5994   38.0       9.0      6.0     0.0
# 1    pos    0.5423    3.0       0.0      0.0     1.0
# 2    neu    0.3612    1.0       0.0      0.0     0.0
# 3    neu    0.9186   20.0       5.0      2.0     1.0
# 4    neu    0.7964  139.0      38.0     22.0     3.0
# 5    pos    0.9423   24.0       0.0      1.0     0.0
# 6    neu    0.6249    2.0       0.0      0.0     0.0
# 7    neu    0.7003  131.0      44.0     17.0     1.0
# 8    neu    0.9432   35.0       8.0      6.0     0.0
# 9    neu    0.9638    2.0       0.0      0.0     0.0
# 10   neu    0.7579    2.0       0.0      0.0     0.0
# 11   pos    0.8442    5.0       0.0      0.0     0.0
# 12   pos    0.7845   15.0       2.0      1.0     0.0
# 13   neu    0.7096   86.0      31.0     23.0     3.0
# 14   neu    0.9337   51.0      41.0     15.0     7.0
# 15   neu    0.5267    2.0       0.0      0.0     0.0
# 16   pos    0.9485   71.0      50.0     22.0     8.0
# ...

# %%
thing = pd.read_csv('../processed twitter data/compiler_full_results.csv')

# %%
thing
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                  Tweet  \
# 0                                                                 Fashion fam, which artworks would you display in your Personal Space in the @some_place Metaverse? \r\n\r\nWe are loving these colourful, groovy digital sculptures by @amber_vittoria and @shantell_martin, two artist collabs with the Potions NFT collection by some·place, minting soon. https://t.co/Hk8JDy6DVp
# ...

# %%
new_compiler = pd.concat([thing[['Tweet']],combi_comp_df], axis=1)

# %%
new_compiler
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                  Tweet  \
# 0                                                                 Fashion fam, which artworks would you display in your Personal Space in the @some_place Metaverse? \r\n\r\nWe are loving these colourful, groovy digital sculptures by @amber_vittoria and @shantell_martin, two artist collabs with the Potions NFT collection by some·place, minting soon. https://t.co/Hk8JDy6DVp
# ...

# %%
new_compiler.to_csv('COMPILER_TOPICS_LABELLED_FINAL.csv', index=False)

# %%
new_compiler['Dominant_Topic'].value_counts(normalize=True)
# Out:
# 0.0    0.413793
# 2.0    0.327586
# 1.0    0.258621
# Name: Dominant_Topic, dtype: float64

# %%
cf1 = new_compiler[new_compiler['Dominant_Topic']== 0.0].sort_values(by=['Topic_Perc_Contrib'], ascending=False).head(15)[['Tweet','Topic_Perc_Contrib']]
cf2 = new_compiler[new_compiler['Dominant_Topic']== 1.0].sort_values(by=['Topic_Perc_Contrib'], ascending=False).head(15)[['Tweet','Topic_Perc_Contrib']]
cf3 = new_compiler[new_compiler['Dominant_Topic']== 2.0].sort_values(by=['Topic_Perc_Contrib'], ascending=False).head(15)[['Tweet','Topic_Perc_Contrib']]

# %%
cf1
# Out:
#                                                                                                                                                                                                                                                                                                                                                         Tweet  \
# 44                          📣 #StayTuned 📣 #EyesOfFashion 📣 \r\nFirst of a kind - 10K Unique, hand drawn, colorful, vibrant &amp; inspiring Eyes of #Fashion NFTs! 👁 By @TaliaZoref 💫 \r\n\r\n@TaliaZoref Forbes 30 under 30, worked with #CHANEL , #Fendi, #Dior &amp; MAC.\r\n\r\n#NFT #NFTCommunity #NFTs #NFTartist #nftgoddesses https://t.co/tJZWCvwqGW
# ...

# %%
cf2
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                  Tweet  \
# 4                                              We are working our way through all of our roadmap milestone giveaways to reward our holders! 🌟\r\n\r\nWe have a few more women-led NFT projects to raffle off \r\n\r\n&amp; \r\n\r\n1 random holder will receive a new, classic black Chanel purse!!! 🍾\r\n\r\nFashion lovers, this one is for you. #eyeconic 🥰 https://t.co/uxIWrdGeMV
# ...

# %%
cf3
# Out:
#                                                                                                                                                                                                                                                                                                                                                     Tweet  \
# 9               @AkisNFTcollect @C_Broadus21 @YearoftheWoman_ We'd love to have your support! We are an 8,888 piece NFT Collection with 250+ hand drawn vibrant traits by \r\n@TaliaZoref inspired by the contrast between the colorful and fun fashion world and the judging eye that belittles the industry. Public mint tomorrow at 3pm UTC / 10am EST
# ...
