# %% [markdown]
# # SNSCRAPE

# %%
import snscrape.modules.twitter as sntwitter
import pandas as pd

# %%
creators = ['gucci','adidas','adidasUS','burberry','LouisVuitton','balenciaga','dolcegabbana','RebeccaMinkoff',
            'KarlLagerfeld','bnv_me','nike','RTFKTstudios','Overpriced_NFT','auroboros_ltd','republiqec',
            'the_fab_ric_ant','SpaceRunnersNFT','MetaTriads','MAVIONworld','SohoKidsNFT','onclickcloset',
            'SCLadiesNFTs','mag_nezyum','web3fashion','DIGITALAX_','prada','balmain','ray_ban','superplastic',
           'givenchy','Bulgariofficial','MaisonValentino','fendi','jimmychoo','Guerlain','MetaBirkins','RalphLauren',
           'dressxcom','tribute_brand','dematerialised','XRCouture','carlingscom']

print("number of creators scraped:",len(creators))

print("query: NFT OR metaverse, english language, not retweet, from 1 Jan 2021 to 1 Mar 2022")

creator_tweets = []

# Using TwitterSearchScraper to scrape data and append tweets to list
for user in creators:
    for i,tweet in enumerate(sntwitter.TwitterSearchScraper('(NFT OR metaverse) from:'+ user + ' lang:en -is:retweet since:2021-01-01 until:2022-03-01').get_items()): 
        if i>2000: #number of tweets you want to scrape
            break

        #declare the attributes to be returned                                        
        creator_tweets.append([tweet.user.username, tweet.date, tweet.id, tweet.content, 
                             tweet.likeCount, tweet.retweetCount, tweet.replyCount, tweet.quoteCount, tweet.mentionedUsers]) 

    
creator_tweets_df = pd.DataFrame(creator_tweets, columns=['Username','Datetime', 'Tweet Id', 'Text', 'Likes', 
                                                 'Retweets', 'Replies',  'Quotes', 'Mentioned'])

print(creator_tweets_df.shape)
print(creator_tweets_df['Username'].value_counts())
# Out:
# number of creators scraped: 42
# query: NFT OR metaverse, english language, not retweet, from 1 Jan 2021 to 1 Mar 2022
# (2332, 9)
# DIGITALAX_         934
# RTFKTstudios       301
# dematerialised     178
# SpaceRunnersNFT    142
# the_fab_ric_ant    125
# RepubliqeC         106
# bnv_me              97
# dolcegabbana        86
# dressxcom           63
# superplastic        56
# XRCouture           35
# AUROBOROS_LTD       32
# Overpriced_NFT      31
# web3fashion         27
# onclickcloset       13
# givenchy            13
# MetaTriads          11
# SohoKidsNFT         11
# KarlLagerfeld       10
# MAVIONworld         10
# gucci                8
# SCLadiesNFTs         7
# mag_nezyum           6
# RebeccaMinkoff       6
# MaisonValentino      5
# Prada                4
# Balmain              3
# ray_ban              3
# Bulgariofficial      2
# Guerlain             2
# Burberry             2
# tribute_brand        2
# jimmychoo            1
# Name: Username, dtype: int64

# %%
media = ['glossyco','highsnobiety','voguemagazine','VogueFrance','BritishVogue','VogueRunway','VOGUEIndia','vogueaustralia',
         'VogueArabia','VogueLiving','voguebusiness','vogue_italia','VogueSpain','Vogue_Taiwan',
         'voguejp','VogueMexico','VogueKorea','VOGUERussia','VOGUE_Germany','NLVogue','voguescandi','vogueturkiye',
        'VogueThailand','HarpersBazaarSG','harpersbazaarus','BazaarArabia','harpersbazaarES','HarpersBazaarJP','ELLEfrance',
         'ELLEmagazine','ELLEUK','ELLEINDIA','elleindonesia','ElleCanada','ELLE_network','ELLESouthAfrica','ELLEaus',
         'Cosmopolitan','CosmopolitanUK','Cosmopolitan_IT','CosmopolitanSA','cosmo_ph','esquire','EsquireUK','EsquirePH',
         'esquiresg','EsquireME','esquireru','CosmopolitanNL','Cosmopolitan_es','Cosmopolitan_fr','Allure_magazine',
         'GQMagazine','BritishGQ','GQAustralia','gqindia','GQStyle','GQdotcoza','VanityFair','TheCut','Dazed','i_D','NylonMag',
         'TeenVogue','wwd','vmagazine','femalesingapore','nytimes','papermagazine','marieclaire']

print("number of media scraped:",len(media))
print("query: NFT OR metaverse, english language, not retweet, from 1 Jan 2021 to 1 Mar 2022")

media_tweets = []

for user in media:
    for i,tweet in enumerate(sntwitter.TwitterSearchScraper('(NFT OR metaverse) from:'+ user + ' lang:en -is:retweet since:2021-01-01 until:2022-03-01').get_items()): 
        if i>2000: #number of tweets you want to scrape
            break

        #declare the attributes to be returned                                        
        media_tweets.append([tweet.user.username, tweet.date, tweet.id, tweet.content, 
                             tweet.likeCount, tweet.retweetCount, tweet.replyCount, tweet.quoteCount, tweet.mentionedUsers]) 

    
# Creating a dataframe from the tweets list above 
media_tweets_df = pd.DataFrame(media_tweets, columns=['Username','Datetime', 'Tweet Id', 'Text', 'Likes', 
                                                 'Retweets', 'Replies',  'Quotes', 'Mentioned'])

print(media_tweets_df.shape)
print(media_tweets_df['Username'].value_counts())
# Out:
# number of media scraped: 70
# query: NFT OR metaverse, english language, not retweet, from 1 Jan 2021 to 1 Mar 2022
# (599, 9)
# voguebusiness      173
# Dazed               77
# highsnobiety        55
# wwd                 52
# nytimes             51
# glossyco            41
# esquiresg           18
# TheCut              17
# VanityFair          17
# i_D                  9
# GQMagazine           9
# papermagazine        9
# voguemagazine        8
# BritishVogue         8
# BritishGQ            7
# NylonMag             7
# VogueRunway          6
# VOGUEIndia           5
# VogueFrance          5
# esquire              5
# Vogue_Taiwan         3
# EsquirePH            3
# BazaarArabia         3
# ELLEmagazine         2
# ELLEUK               2
# esquireru            1
# VogueArabia          1
# EsquireME            1
# harpersbazaarus      1
# ELLEINDIA            1
# vmagazine            1
# ELLEfrance           1
# Name: Username, dtype: int64

# %%
play = []

# Using TwitterSearchScraper to scrape data and append tweets to list
for i,tweet in enumerate(sntwitter.TwitterSearchScraper('(NFT OR metaverse) from:glossyco lang:en -is:retweet since:2021-01-01 until:2022-03-01').get_items()): 
    if i>1000: #number of tweets you want to scrape
        break
    
    #declare the attributes to be returned                                        
    play.append([ tweet.user.username, tweet.date, tweet.id, tweet.content,
                         tweet.likeCount, tweet.retweetCount, tweet.replyCount, tweet.quoteCount, tweet.mentionedUsers]) 
    
    
# Creating a dataframe from the tweets list above 
playdf = pd.DataFrame(play, columns=['Datetime', 'Tweet Id', 'Text', 'Username', 'Likes', 
                                                 'Retweets', 'Replies',  'Quotes','Mentioned'])
                                                        
playdf
# Out:
#     Datetime                  Tweet Id                 Text  \
# 0   glossyco 2022-02-26 21:00:05+00:00  1497677875876663310
# 1   glossyco 2022-02-23 16:01:20+00:00  1496515528546033666
# 2   glossyco 2022-02-19 20:00:24+00:00  1495126139764891652
# 3   glossyco 2022-02-19 15:00:42+00:00  1495050716553035776
# 4   glossyco 2022-02-15 16:00:00+00:00  1493616089842032650
# 5   glossyco 2022-02-10 16:00:10+00:00  1491804190850617346
# 6   glossyco 2022-02-07 16:01:17+00:00  1490717308951666695
# 7   glossyco 2022-02-07 15:01:05+00:00  1490702159901511684
# 8   glossyco 2022-02-02 14:00:48+00:00  1488875051126562818
# 9   glossyco 2022-01-19 15:00:56+00:00  1483816753117421572
# 10  glossyco 2022-01-18 14:00:31+00:00  1483439158672691207
# 11  glossyco 2022-01-11 14:00:48+00:00  1480902515629731843
# 12  glossyco 2022-01-06 14:00:54+00:00  1479090603535257603
# 13  glossyco 2022-01-03 20:00:34+00:00  1478093953404710917
# 14  glossyco 2021-12-23 16:00:00+00:00  1474047146387292165
# ...

# %%
print("query: voguesingapore, NFT OR metaverse, english language, not retweet, from 1 Jan 2021 to 1 Mar 2022")

vogue_tweets = []

for i,tweet in enumerate(sntwitter.TwitterSearchScraper('(NFT OR metaverse) from:voguesingapore lang:en -is:retweet since:2021-01-01 until:2022-03-01').get_items()): 
    if i>2000: #number of tweets you want to scrape
        break

    #declare the attributes to be returned                                        
    vogue_tweets.append([tweet.user.username, tweet.date, tweet.id, tweet.content, 
                         tweet.likeCount, tweet.retweetCount, tweet.replyCount, tweet.quoteCount, tweet.mentionedUsers]) 

    
# Creating a dataframe from the tweets list above 
vogue_tweets_df = pd.DataFrame(vogue_tweets, columns=['Username','Datetime', 'Tweet Id', 'Text', 'Likes', 
                                                 'Retweets', 'Replies',  'Quotes', 'Mentioned'])

print(vogue_tweets_df.shape)
print(vogue_tweets_df['Username'].value_counts())
# Out:
# query: voguesingapore, NFT OR metaverse, english language, not retweet, from 1 Jan 2021 to 1 Mar 2022
# (41, 9)
# voguesingapore    41
# Name: Username, dtype: int64

# %%
general = ['fashion AND (NFT OR metaverse)']
#fashionnft


print("number of general scraped:",len(general))
print("query: english language, not retweet, from 1 Jan 2021 to 1 Mar 2022")

general_tweets = []

for query in general:
    for i,tweet in enumerate(sntwitter.TwitterSearchScraper( query + ' lang:en -is:retweet since:2021-01-01 until:2022-03-01').get_items()): 
        if i>15000: #number of tweets you want to scrape
            break

        #declare the attributes to be returned                                        
        general_tweets.append([tweet.user.username, tweet.date, tweet.id, tweet.content, 
                             tweet.likeCount, tweet.retweetCount, tweet.replyCount, tweet.quoteCount, tweet.mentionedUsers]) 

    
# Creating a dataframe from the tweets list above 
general_tweets_df = pd.DataFrame(general_tweets, columns=['Username','Datetime', 'Tweet Id', 'Text', 'Likes', 
                                                 'Retweets', 'Replies',  'Quotes', 'Mentioned'])

print(general_tweets_df.shape)
print(general_tweets_df['Username'].value_counts())
# Out:
# number of general scraped: 1
# query: english language, not retweet, from 1 Jan 2021 to 1 Mar 2022
# (15001, 9)
# TheNFTRebel        95
# fakeTakeDump       94
# PartnersNFT        72
# additionalrules    63
# metav3rse_         57
#                    ..
# Daichi555_eth       1
# AjayPatel37527      1
# GohDRoger           1
# psycolin            1
# RobStriar           1
# Name: Username, Length: 9415, dtype: int64

# %%
compiler = ['EyesoFashionNFT','FashionArtNFT', 'NotYourBroNFT','marcopoker', 'shawn_pyfrom', 'Brytehall']

print("number of compiler scraped:",len(compiler))
print("query: NFT OR metaverse, english language, not retweet, from 1 Jan 2021 to 1 Mar 2022")

compiler_tweets = []

for user in compiler:
    for i,tweet in enumerate(sntwitter.TwitterSearchScraper('Fashion AND (NFT OR metaverse) from:'+ user + ' lang:en -is:retweet since:2021-01-01 until:2022-03-01').get_items()): 
        if i>2000: #number of tweets you want to scrape
            break

        #declare the attributes to be returned                                        
        compiler_tweets.append([tweet.user.username, tweet.date, tweet.id, tweet.content, 
                             tweet.likeCount, tweet.retweetCount, tweet.replyCount, tweet.quoteCount, tweet.mentionedUsers]) 

    
# Creating a dataframe from the tweets list above 
compiler_tweets_df = pd.DataFrame(compiler_tweets, columns=['Username','Datetime', 'Tweet Id', 'Text', 'Likes', 
                                                 'Retweets', 'Replies',  'Quotes', 'Mentioned'])


print(compiler_tweets_df.shape)
print(compiler_tweets_df['Username'].value_counts())
# Out:
# number of compiler scraped: 6
# query: NFT OR metaverse, english language, not retweet, from 1 Jan 2021 to 1 Mar 2022
# (54, 9)
# EyesoFashionNFT    45
# Brytehall           8
# FashionArtNFT       1
# Name: Username, dtype: int64

# %%
general_tweets_df['Text']
# Out:
# 0       Huge News for the Community @FierceStudioNFT !...
# 1       Why do we need #FashionTech ? What should you ...
# 2       Proud to be the stylist of @Praverse, praverse...
# 3       💰 Coins Giveaway 💰 2,000 coins to everyone tha...
# 4       @screentimes @realFaithTribe is revolutionizin...
#                               ...
# 1653    Working in on the #NFT series of my project “N...
# 1654    Outtake long time ago with the great  @sokhnaf...
# 1655    🔥@CryptoSoltan x @harrisonfirst🔥\nFWD Collecti...
# 1656    Get Your Fashion NFT now! #fashion #NFT\n\nPur...
# 1657    'Run Rosie Run' by @patternbase\n\n🌹1 of 3 🌹• ...
# Name: Text, Length: 1658, dtype: object

# %%
print("query: lunaikuta, NFT OR metaverse, english language, not retweet, from 1 Jan 2021 to 1 Mar 2022")

luna_tweets = []

for i,tweet in enumerate(sntwitter.TwitterSearchScraper('(afterlife OR vogue) from:lunaikuta lang:en -is:retweet since:2021-01-01 until:2022-03-01').get_items()): 
    if i>2000: #number of tweets you want to scrape
        break

    #declare the attributes to be returned                                        
    luna_tweets.append([tweet.user.username, tweet.date, tweet.id, tweet.content, 
                         tweet.likeCount, tweet.retweetCount, tweet.replyCount, tweet.quoteCount, tweet.mentionedUsers]) 

    
# Creating a dataframe from the tweets list above 
luna_tweets_df = pd.DataFrame(luna_tweets, columns=['Username','Datetime', 'Tweet Id', 'Text', 'Likes', 
                                                 'Retweets', 'Replies',  'Quotes', 'Mentioned'])

print(luna_tweets_df.shape)
print(luna_tweets_df['Username'].value_counts())
luna_tweets_df.head()
# Out:
# query: lunaikuta, NFT OR metaverse, english language, not retweet, from 1 Jan 2021 to 1 Mar 2022
# (19, 9)
# lunaikuta    19
# Name: Username, dtype: int64
#     Username                  Datetime             Tweet Id  \
# 0  lunaikuta 2022-02-08 11:40:20+00:00  1491014025911488514
# 1  lunaikuta 2022-02-04 22:10:53+00:00  1489723157975998464
# 2  lunaikuta 2022-02-04 17:55:47+00:00  1489658962710433795
# 3  lunaikuta 2022-02-03 03:25:50+00:00  1489077643223842817
# 4  lunaikuta 2022-02-02 21:30:24+00:00  1488988193516965892
#
#                                                 Text  Likes  Retweets  \
# 0  ❀ 12 works, 12 reserves, 12 months of Afterlif...     67        12
# 1          Sweet Pea - 12 Months of Afterlife: April      3         0
# 2  @Me_MartinGarcia @voguesingapore @Me_MartinGar...      0         0
# 3             Orchid - 12 Months of Afterlife: March      2         0
# 4        Scabiosa - 12 Months of Afterlife: February      1         0
#
# ...

# %%
import numpy as np
import re
import nltk
from nltk.corpus import stopwords
stop_list = nltk.corpus.stopwords.words('english')
# The following list is to further remove some frequent words in SGNews.
stop_list += ['would', 'said', 'say', 'year', 'day', 'also', 'first', 'last', 'one', 'two', 'people', 'told', 'new', 'could', 'singapore', 'three', 'may', 'like', 'world', 'since', 'nft', 'metaverse','fashion','amp', 'digital','project','nfts']
from nltk.stem.porter import *
stemmer = PorterStemmer()

def clean_tweet(tweet):
    if type(tweet) == np.float:
        return ""
    temp = tweet.lower()
    temp = re.sub("'", "", temp) # to avoid removing contractions in english
    temp = re.sub("@[A-Za-z0-9_]+","", temp)
    #temp = re.sub("#[A-Za-z0-9_]+","", temp)
    temp = re.sub(r'http\S+', '', temp)
    temp = re.sub('[()!?]', ' ', temp)
    temp = re.sub('\[.*?\]',' ', temp)
    temp = re.sub("[^a-z0-9]"," ", temp)
    temp = temp.split()
    temp = [w for w in temp if not w in stop_list]
    temp = [stemmer.stem(w) for w in temp]
    temp = " ".join(word for word in temp)
    return temp

# %%
#tweet_text_list = luna_tweets_df['Text'].tolist()
#tweet_text_list = vogue_tweets_df['Text'].tolist()
#tweet_text_list = compiler_tweets_df['Text'].tolist()
tweet_text_list = general_tweets_df['Text'].tolist()
tweet_text_list
# Out:
# ['“Digital fashion and virtual spaces are expanding beyond games; Roblox doesn’t even identify as a gaming platform. At the upcoming Metaverse Fashion Week, many brands will be selling both digital and physical versions of designs, while Gucci and Adidas ar…https://t.co/XEPn6d1B9T',
#  '⚡Shiba Inu To Launch New NFT Fashion Collection With British Designer John Richmond  🥻🐶 #NFT #SHIB #shibarmy #cryptocurrency #CryptoNews #Crypto ⚡\nhttps://t.co/DX5JzxXvZd',
#  'Decentraland to Host Metaverse Fashion Week With Tommy Hilfiger, Dolce &amp; Gabbana, Selfridges\n\nThe blockchain-based virtual world Decentraland has announced the launch of a Metaverse Fashion Week that is scheduled to take place on March 24 – 27, 2022.  https://t.co/jlLdLoStO0 https://t.co/xMO6jVL1GH',
# ...

# %%
results = [clean_tweet(tw) for tw in tweet_text_list]
# Out:
# C:\Users\Parveen\AppData\Local\Temp/ipykernel_37792/996903025.py:12: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   if type(tweet) == np.float:

# %%
results
# Out:
# ['virtual space expand beyond game roblox even identifi game platform upcom week mani brand sell physic version design gucci adida ar',
#  'shiba inu launch collect british design john richmond shib shibarmi cryptocurr cryptonew crypto',
#  'decentraland host week tommi hilfig dolc gabbana selfridg blockchain base virtual decentraland announc launch week schedul take place march 24 27 2022',
#  'set remind upcom space learn speak dev team spaceshost twitterspac womeninnft dressmak',
#  'happen hype drop seri contemporari illustr fran oi berthoud collabor x mad xr x foundat sozzani accept offer',
#  'apien join biggest movement today 8pm est discuss way take apien next level make us differ special',
#  'learn wearabl partnership web3',
#  'retail play role seen rebecca minkoff launch collect york week dolc gabbana r l surpris drop gener 5m sale',
#  'week brand display accessori',
#  'check photograph x collag motion artist collect',
#  'editori hub spotlight mirl hilari',
# ...

# %%
from nltk.tokenize import RegexpTokenizer
tokenizer = RegexpTokenizer(r'\w+')
porter_stemmer = PorterStemmer()

media_words = []
for tweet_text in results:
    tokens = tokenizer.tokenize(tweet_text)
    media_words.extend(tokens)

print(len(media_words))
media_words
# Out:
# 193667
# ['virtual',
#  'space',
#  'expand',
#  'beyond',
#  'game',
#  'roblox',
#  'even',
#  'identifi',
#  'game',
#  'platform',
#  'upcom',
#  'week',
#  'mani',
#  'brand',
#  'sell',
#  'physic',
#  'version',
#  'design',
#  'gucci',
#  'adida',
#  'ar',
#  'shiba',
#  'inu',
#  'launch',
#  'collect',
#  'british',
#  'design',
#  'john',
#  'richmond',
#  'shib',
#  'shibarmi',
#  'cryptocurr',
#  'cryptonew',
#  'crypto',
#  'decentraland',
#  'host',
#  'week',
#  'tommi',
#  'hilfig',
#  'dolc',
#  'gabbana',
#  'selfridg',
#  'blockchain',
#  'base',
#  'virtual',
#  'decentraland',
#  'announc',
#  'launch',
#  'week',
#  'schedul',
#  'take',
#  'place',
#  'march',
#  '24',
#  '27',
#  '2022',
#  'set',
#  'remind',
#  'upcom',
#  'space',
#  'learn',
#  'speak',
#  'dev',
#  'team',
#  'spaceshost',
#  'twitterspac',
#  'womeninnft',
#  'dressmak',
#  'happen',
#  'hype',
#  'drop',
#  'seri',
#  'contemporari',
#  'illustr',
#  'fran',
#  'oi',
#  'berthoud',
# ...

# %%
import collections
media_frequency = collections.Counter(media_words)
media_dic = dict(media_frequency)
print(len(media_dic))

a1_sorted_keys = sorted(media_dic, key=media_dic.get, reverse=True)
for r in a1_sorted_keys:
    print(r, media_dic[r])
# Out:
# 14628
# brand 1921
# collect 1475
# altava 1333
# design 1307
# art 1290
# week 1195
# nftcommun 1185
# come 1116
# show 973
# futur 968
# ar 873
# virtual 870
# runner 850
# look 840
# 1 817
# join 809
# love 805
# space 790
# get 786
# industri 785
# luxuri 749
# crypto 745
# go 720
# game 699
# launch 678
# creat 674
# team 655
# commun 641
# see 630
# true 625
# possibl 622
# want 600
# real 595
# check 591
# web3 571
# 2 566
# great 561
# ootd 560
# make 556
# 3 556
# nftart 539
# good 529
# decentraland 521
# blockchain 520
# work 517
# collabor 502
# artist 495
# high 492
# 0 491
# bring 470
# buy 466
# us 464
# eth 461
# runfam 457
# cloth 455
# mint 454
# discord 449
# nftcollector 439
# think 438
# next 431
# via 416
# time 414
# drop 413
# gucci 410
# follow 408
# take 404
# nftcollect 395
# nftartist 393
# best 389
# physic 383
# big 379
# style 378
# opensea 371
# use 370
# uniqu 367
# music 367
# build 365
# im 359
# 3d 356
# know 350
# excit 349
# start 343
# ...

# %%
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt

comment_words = ''

# iterate through list
for tweet_text in results:
    # split the text into tokens
    tokens = tweet_text.split()
    # Append tokens to string comment_words
    comment_words += " ".join(tokens)+" "

# Let's make a word cloud
wordcloud = WordCloud(width = 800, height = 800,
                background_color ='white',
                #stopwords = stopwords,
                min_font_size = 10).generate(comment_words)
 
# plot the WordCloud image                      
plt.figure(figsize = (8, 8), facecolor = None)
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad = 0)
 
plt.show()
