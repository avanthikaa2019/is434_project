# %%
import pandas as pd

# %%
media_tweets = pd.read_csv('processed twitter data/media_results.csv')
creator_tweets = pd.read_csv('processed twitter data/creator_results.csv')

# %%
media_tweets
# Out:
#                                                   Tweet  \
# 0     Metaverse launches have been frequent in the l...
# 1     Metaverse launches have been frequent in the l...
# 2     Positioned as a physical metaverse influencer ...
# 3     Marketers discussed ways into the metaverse, a...
# 4     Positioned as a physical metaverse influencer ...
# ...                                                 ...
# 1034  Poly Auction Hong Kong is joining hands with d...
# 1035  The Hong Kong director celebrates the 30th ann...
# 1036  Poly Auction Hong Kong is joining hands with d...
# 1037  The Hong Kong director celebrates the 30th ann...
# 1038  Luxury luggage brand, Rimowa, on their first-e...
#
#                                               Processed
# 0     launches frequent brands including gucci adida...
# 1     launches frequent brands like launching accord...
# 2     positioned physical influencer creator hub 1 2...
# 3     marketers discussed ways among topics digiday ...
# ...

# %%
all_df = pd.concat([media_tweets,creator_tweets],ignore_index = True)

# %%
all_df
# Out:
#                                                   Tweet  \
# 0     Metaverse launches have been frequent in the l...
# 1     Metaverse launches have been frequent in the l...
# 2     Positioned as a physical metaverse influencer ...
# 3     Marketers discussed ways into the metaverse, a...
# 4     Positioned as a physical metaverse influencer ...
# ...                                                 ...
# 4383  @AB_solo You can try again tomorrow… or the ne...
# 4384  @KaddouraHoussam The made-to-order Rogue bag i...
# 4385  @Thatjpeg_ Our first NFT will be available at ...
# 4386  @uuuulllii We’re offering a limited quantity o...
# 4387  ✨ Why we’re entering the NFT space: to mark th...
#
#                                               Processed
# 0     launches frequent brands including gucci adida...
# 1     launches frequent brands like launching accord...
# 2     positioned physical influencer creator hub 1 2...
# 3     marketers discussed ways among topics digiday ...
# ...

# %%
all_labelled = pd.read_csv('Twitter LDA CSV/topics_labelled_all.csv')

# %%
all_labelled
# Out:
#       Document_No  Dominant_Topic  Topic_Perc_Contrib  \
# 0               0             0.0              0.3754
# 1               1             0.0              0.3928
# 2               2             3.0              0.3671
# 3               3             3.0              0.3252
# 4               4             3.0              0.3499
# ...           ...             ...                 ...
# 4377         4377             0.0              0.3180
# 4378         4378             2.0              0.3340
# 4379         4379             1.0              0.3005
# 4380         4380             1.0              0.3707
# 4381         4381             3.0              0.4619
#
#                                                Keywords  \
# 0     drop, fashion, love, world, big, new, time, be...
# 1     drop, fashion, love, world, big, new, time, be...
# 2     collection, physical, digitalax, sell, owner, ...
# 3     collection, physical, digitalax, sell, owner, ...
# ...

# %%
all_labelled.isna().sum()
# Out:
# Document_No              0
# Dominant_Topic           0
# Topic_Perc_Contrib       0
# Keywords                 0
# Text                  3285
# dtype: int64
